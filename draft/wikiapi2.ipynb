# %% [markdown]
# # Wikiapi functions

# %% [markdown]
# ## Agent Authentication

# %% [markdown]
# Initialize the agent, specifying contact information for if they need to communicate something to you.

# %%
import wikipediaapi
agent = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'en')

# %% [markdown]
# ## Page Object

# %% [markdown]
# See examples of attributes below.

# %%
page_py = agent.page('Python_(programming_language)')

print("fullurl:", page_py.fullurl)
print("canonicalurl:", page_py.canonicalurl)
print("pageid:", page_py.pageid)
print("displaytitle:", page_py.displaytitle)
print("talkid:", page_py.talkid)

print("Page - Exists: %s" % page_py.exists())
print("Page - Title: %s" % page_py.title)
print("Page - Summary: %s" % page_py.summary[:60])
print("Page - Language: %s" % page_py.language)
print("Page - Namespace: %s" % page_py.namespace)
print("Page - Sections: %s" % [section.title for section in page_py.sections])

print("\n\n")

for attribute in dir(page_py):
    if not attribute.startswith("_"):
        print(attribute)
# Out:
# fullurl: https://en.wikipedia.org/wiki/Python_(programming_language)
# canonicalurl: https://en.wikipedia.org/wiki/Python_(programming_language)
# pageid: 23862
# displaytitle: Python (programming language)
# talkid: 24235
# Page - Exists: True
# Page - Title: Python (programming language)
# Page - Summary: Python is a high-level, general-purpose programming language
# Page - Language: en
# Page - Namespace: 0
# Page - Sections: ['History', 'Design philosophy and features', 'Syntax and semantics', 'Programming examples', 'Libraries', 'Development environments', 'Implementations', 'Development', 'API documentation generators', 'Naming', 'Popularity', 'Uses', 'Languages influenced by Python', 'See also', 'References', 'Further reading', 'External links']
#
#
#
# ATTRIBUTES_MAPPING
# backlinks
# categories
# categorymembers
# exists
# langlinks
# language
# links
# namespace
# section_by_title
# sections
# sections_by_title
# summary
# text
# title
# wiki

# %% [markdown]
# ## Get all the articles in a category

# %%
def print_categories(page):
        categories = page.categories
        for title in sorted(categories.keys()):
            print("%s: %s" % (title, categories[title]))


print("Categories")
print_categories(page_py)
# Out:
# Categories
# Category:All articles containing potentially dated statements: Category:All articles containing potentially dated statements (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from 2008: Category:Articles containing potentially dated statements from 2008 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from 2020: Category:Articles containing potentially dated statements from 2020 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from December 2022: Category:Articles containing potentially dated statements from December 2022 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from June 2023: Category:Articles containing potentially dated statements from June 2023 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from March 2024: Category:Articles containing potentially dated statements from March 2024 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from October 2023: Category:Articles containing potentially dated statements from October 2023 (id: ??, ns: 14)
# Category:Articles with BNF identifiers: Category:Articles with BNF identifiers (id: ??, ns: 14)
# Category:Articles with BNFdata identifiers: Category:Articles with BNFdata identifiers (id: ??, ns: 14)
# Category:Articles with FAST identifiers: Category:Articles with FAST identifiers (id: ??, ns: 14)
# Category:Articles with GND identifiers: Category:Articles with GND identifiers (id: ??, ns: 14)
# Category:Articles with J9U identifiers: Category:Articles with J9U identifiers (id: ??, ns: 14)
# Category:Articles with LCCN identifiers: Category:Articles with LCCN identifiers (id: ??, ns: 14)
# Category:Articles with NKC identifiers: Category:Articles with NKC identifiers (id: ??, ns: 14)
# Category:Articles with SUDOC identifiers: Category:Articles with SUDOC identifiers (id: ??, ns: 14)
# Category:Articles with example Python (programming language) code: Category:Articles with example Python (programming language) code (id: ??, ns: 14)
# Category:Articles with short description: Category:Articles with short description (id: ??, ns: 14)
# Category:Class-based programming languages: Category:Class-based programming languages (id: ??, ns: 14)
# Category:Computer science in the Netherlands: Category:Computer science in the Netherlands (id: ??, ns: 14)
# Category:Concurrent programming languages: Category:Concurrent programming languages (id: ??, ns: 14)
# Category:Cross-platform free software: Category:Cross-platform free software (id: ??, ns: 14)
# Category:Cross-platform software: Category:Cross-platform software (id: ??, ns: 14)
# Category:Dutch inventions: Category:Dutch inventions (id: ??, ns: 14)
# Category:Dynamically typed programming languages: Category:Dynamically typed programming languages (id: ??, ns: 14)
# Category:Educational programming languages: Category:Educational programming languages (id: ??, ns: 14)
# Category:High-level programming languages: Category:High-level programming languages (id: ??, ns: 14)
# Category:Information technology in the Netherlands: Category:Information technology in the Netherlands (id: ??, ns: 14)
# Category:Multi-paradigm programming languages: Category:Multi-paradigm programming languages (id: ??, ns: 14)
# Category:Notebook interface: Category:Notebook interface (id: ??, ns: 14)
# Category:Object-oriented programming languages: Category:Object-oriented programming languages (id: ??, ns: 14)
# Category:Pages using Sister project links with hidden wikidata: Category:Pages using Sister project links with hidden wikidata (id: ??, ns: 14)
# Category:Pages using Sister project links with wikidata namespace mismatch: Category:Pages using Sister project links with wikidata namespace mismatch (id: ??, ns: 14)
# Category:Pattern matching programming languages: Category:Pattern matching programming languages (id: ??, ns: 14)
# Category:Programming languages: Category:Programming languages (id: ??, ns: 14)
# Category:Programming languages created in 1991: Category:Programming languages created in 1991 (id: ??, ns: 14)
# Category:Python (programming language): Category:Python (programming language) (id: ??, ns: 14)
# Category:Scripting languages: Category:Scripting languages (id: ??, ns: 14)
# Category:Short description matches Wikidata: Category:Short description matches Wikidata (id: ??, ns: 14)
# Category:Text-oriented programming languages: Category:Text-oriented programming languages (id: ??, ns: 14)
# Category:Use dmy dates from November 2021: Category:Use dmy dates from November 2021 (id: ??, ns: 14)

# %% [markdown]
# ## Get all category members

# %%
def print_categorymembers(categorymembers, level=0, max_level=1):
        for c in categorymembers.values():
            print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
            if c.ns == wikipediaapi.Namespace.CATEGORY and level < max_level:
                print_categorymembers(c.categorymembers, level=level + 1, max_level=max_level)

agent_es = wikipediaapi.Wikipedia('MyProjectName (merlin@example.com)', 'es')
cat = agent_es.page("Category:Ciencias de la vida")
print("Category members: Category:Ciencias de la vida")


print_categorymembers(cat.categorymembers, level=0, max_level=3)
# Out:
# Category members: Category:Ciencias de la vida
# *: Ciencias de la vida (ns: 0)
# *: Euroliga de Ciencias de la Vida (ns: 0)
# *: Categoría:Bioingeniería (ns: 14)
# **: Agricultura molecular (ns: 0)
# **: Amortiguador reológico (ns: 0)
# **: Bioastronáutica (ns: 0)
# **: Biocibernética (ns: 0)
# **: Biocompatibilidad (ns: 0)
# **: Biofabricación (ns: 0)
# **: Bioimpresión 3D (ns: 0)
# **: Bioinformática (ns: 0)
# **: BIOMED (ns: 0)
# **: Biorreactor (ns: 0)
# **: Cerámica piezoeléctrica (ns: 0)
# **: E-NABLE (ns: 0)
# **: Edición de calidad (ns: 0)
# **: Fed-batch (ns: 0)
# **: Gene targeting (ns: 0)
# **: Hígado artificial (ns: 0)
# **: Ingeniería biológica (ns: 0)
# **: Ingeniería biónica (ns: 0)
# **: Ingeniería de tejidos (ns: 0)
# **: Ingeniería genética humana (ns: 0)
# **: Instituto de Investigación Biomédica de Lérida (ns: 0)
# **: Instituto de Investigación Biomédica (ns: 0)
# **: Instituto Maimónides de Investigación Biomédica de Córdoba (ns: 0)
# **: Instituto Nacional de Bioinformática (ns: 0)
# **: Material biocompatible (ns: 0)
# **: TALEN (ns: 0)
# **: Transformación genética mediada por Agrobacterium rhizogenes (ns: 0)
# **: Categoría:Bioingenieros (ns: 14)
# ***: Rebecca R. Richards-Kortum (ns: 0)
# ***: Rober Malkin (ns: 0)
# ***: Carolina Serrano Larrea (ns: 0)
# **: Categoría:Biología sintética (ns: 14)
# ***: Biología sintética (ns: 0)
# ***: Atoxilo (ns: 0)
# ***: Carne cultivada (ns: 0)
# ***: Célula artificial (ns: 0)
# ***: Circuito biológico sintético (ns: 0)
# ***: Cirugía sin sangre (ns: 0)
# ***: Fotografía bacteriana (ns: 0)
# ***: International Genetically Engineered Machine (ns: 0)
# ***: Island Conservation (ns: 0)
# ***: Mycoplasma laboratorium (ns: 0)
# ***: Organoide cerebral (ns: 0)
# ***: Piel artificial (ns: 0)
# ***: Represilador (ns: 0)
# ***: Revive & Restore (ns: 0)
# ***: Sustituto sanguíneo (ns: 0)
# ***: Vida sintética (ns: 0)
# ***: Virología sintética (ns: 0)
# ***: Xenobot (ns: 0)
# **: Categoría:Biomecánica (ns: 14)
# ***: Biomecánica (ns: 0)
# ***: Cadena cinética (Biomecánica) (ns: 0)
# ***: Criterio de lesión encefálica (ns: 0)
# ***: Gerontokinesiología (ns: 0)
# ***: Hidroesqueleto (ns: 0)
# ***: Kinesiología (ns: 0)
# ***: Ley cuadrático-cúbica (ns: 0)
# ***: Locomoción rotativa en sistemas vivos (ns: 0)
# ***: Nanobiomecánica (ns: 0)
# ***: Postura corporal neutra (ns: 0)
# ***: Pronosupinación del pie en carrera (ns: 0)
# ***: Reflejo vestíbulo emocional (ns: 0)
# ***: Suspensión mandibular (ns: 0)
# ***: Tejido blando (ns: 0)
# ***: Teoría constructal (ns: 0)
# ***: Categoría:Locomoción (ns: 14)
# ****: 9,10-ditioantraceno (ns: 0)
# ****: Análisis de la marcha (ns: 0)
# ****: Andadura (ns: 0)
# ****: Bipedestación (ns: 0)
# ****: Braquiación (ns: 0)
# ****: Comportamiento suspensorio (ns: 0)
# ****: Corredor (biología) (ns: 0)
# ****: De puntillas (ns: 0)
# ****: Digitígrado (ns: 0)
# ****: Durotaxis (ns: 0)
# ****: El movimiento de los animales (ns: 0)
# ****: Física del vuelo (ns: 0)
# ****: Galope (ns: 0)
# ****: Galope de doble suspensión (ns: 0)
# ****: Haptotaxis (ns: 0)
# ****: Locomoción aérea (ns: 0)
# ****: Locomoción animal (ns: 0)
# ****: Locomoción rotativa en sistemas vivos (ns: 0)
# ****: Locomoción terrestre (ns: 0)
# ****: Mimetismo locomotor (ns: 0)
# ****: Pezuña (ns: 0)
# ****: Plantígrado (ns: 0)
# ****: Salto (locomoción) (ns: 0)
# ****: Salto de rebote (ns: 0)
# ****: Sesilidad (biología) (ns: 0)
# ****: Ungulígrado (ns: 0)
# ****: Categoría:Andar (ns: 14)
# ****: Categoría:Motilidad celular (ns: 14)
# ****: Categoría:Vuelo en animales (ns: 14)
# **: Categoría:Hábitats humanos (ns: 14)
# ***: Hábitat humano (ns: 0)
# ***: Bastle house (ns: 0)
# ***: Boma (recinto) (ns: 0)
# ***: Complejo (arquitectura) (ns: 0)
# ***: Cortiço (ns: 0)
# ***: Dominio (territorio) (ns: 0)
# ***: Edificio autónomo (ns: 0)
# ***: Finca (ns: 0)
# ***: Finca rústica (ns: 0)
# ***: Granja agrícola (ns: 0)
# ***: Hábitat espacial (ns: 0)
# ***: Kraal (ns: 0)
# ***: Mesohábitat (ns: 0)
# ***: Mouza (ns: 0)
# ***: Pueblo pesquero (ns: 0)
# ***: Yaodong (ns: 0)
# ***: Categoría:Áreas urbanas (ns: 14)
# ****: Categoría:Áreas urbanas de Filipinas (ns: 14)
# ***: Categoría:Comunidad intencional (ns: 14)
# ****: Comunidad intencional (ns: 0)
# ****: Awra Amba (ns: 0)
# ****: Brook Farm (ns: 0)
# ****: Colonia Cecilia (ns: 0)
# ****: Comuna (ns: 0)
# ****: Comunidades de El Arca (Lanza del Vasto) (ns: 0)
# ****: Comunidades utópicas (ns: 0)
# ****: Covivienda (ns: 0)
# ****: Ecoaldea (ns: 0)
# ****: Monacato (ns: 0)
# ****: Moshav (ns: 0)
# ****: Tamera (ns: 0)
# ****: Walden dos (ns: 0)
# ****: ZEGG (ns: 0)
# ****: Zona Autónoma de Capitol Hill (ns: 0)
# ****: Categoría:Cooperativas de vivienda (ns: 14)
# ****: Categoría:Comunidades cristianas (ns: 14)
# ****: Categoría:Kibutz (ns: 14)
# ****: Categoría:Moshavim (ns: 14)
# ****: Categoría:Supervivencia (ns: 14)
# ***: Categoría:Explotaciones agrícolas (ns: 14)
# ****: Propiedad imperial (Antigua Roma) (ns: 0)
# ****: Villa rustica (ns: 0)
# ***: Categoría:Hábitats submarinos (ns: 14)
# ****: Piscina lunar (ns: 0)
# ***: Categoría:Hospedajes (ns: 14)
# ****: Hospedaje (viaje) (ns: 0)
# ****: Museo Rosa Bonheur (ns: 0)
# ****: Categoría:Mansio (ns: 14)
# ***: Categoría:Localidades por tipo (ns: 14)
# ****: Categoría:Localidades de Alemania por tipo (ns: 14)
# ****: Categoría:Localidades de Argelia por tipo (ns: 14)
# ****: Categoría:Localidades de Austria por tipo (ns: 14)
# ****: Categoría:Localidades de Costa Rica por tipo (ns: 14)
# ****: Categoría:Localidades de España por tipo (ns: 14)
# ****: Categoría:Localidades de Honduras por tipo (ns: 14)
# ****: Categoría:Localidades de Hungría por tipo (ns: 14)
# ****: Categoría:Localidades de Irak por tipo (ns: 14)
# ****: Categoría:Localidades de Irán por tipo (ns: 14)
# ****: Categoría:Localidades de Italia por tipo (ns: 14)
# ****: Categoría:Localidades de Jordania por tipo (ns: 14)
# ****: Categoría:Localidades de México por tipo (ns: 14)
# ****: Categoría:Localidades de Nueva Zelanda por tipo (ns: 14)
# ****: Categoría:Localidades de los Países Bajos por tipo (ns: 14)
# ****: Categoría:Localidades de Paraguay por tipo (ns: 14)
# ****: Categoría:Localidades de Polonia por tipo (ns: 14)
# ****: Categoría:Localidades de Portugal por tipo (ns: 14)
# ****: Categoría:Localidades de Suiza por tipo (ns: 14)
# ****: Categoría:Localidades de Uruguay por tipo (ns: 14)
# ****: Categoría:Ciudades por tipo (ns: 14)
# ****: Categoría:Localidades anarquistas (ns: 14)
# ****: Categoría:Capitales (ns: 14)
# ****: Categoría:Ciudades ficticias (ns: 14)
# ****: Categoría:Localidades establecidas por fecha de fundación (ns: 14)
# ****: Categoría:Localidades con ferrocarril metropolitano (ns: 14)
# ****: Categoría:Localidades fronterizas (ns: 14)
# ****: Categoría:Localidades planificadas (ns: 14)
# ****: Categoría:Localidades portuarias (ns: 14)
# ****: Categoría:Localidades rurales (ns: 14)
# ****: Categoría:Suburbios (ns: 14)
# ***: Categoría:Yacimientos arqueológicos (ns: 14)
# ****: Yacimiento arqueológico (ns: 0)
# ****: Adloun (ns: 0)
# ****: Aigyr-Zhal 2 (ns: 0)
# ****: Arte rupestre en México (ns: 0)
# ****: Bajada Km 57 (ns: 0)
# ****: Barcos de Salme (ns: 0)
# ****: Cañón de las Tinaja Cucapá (ns: 0)
# ****: Castro de la Loma (ns: 0)
# ****: Cuddie Springs (ns: 0)
# ****: Cueva del Guerrero (ns: 0)
# ****: Cultura de la daga de bronce (ns: 0)
# ****: Dolmen de Santa Inés (ns: 0)
# ****: El Vallecito (Baja California) (ns: 0)
# ****: Expolio arqueológico y artístico (ns: 0)
# ****: Usuaria:Fresa swiftie/Taller/El Dolmen de Santa Inés (ns: 2)
# ****: Hipogeo de Torre del Ram (ns: 0)
# ****: Huaca Casa Rosada (ns: 0)
# ****: Isla Nipisat (ns: 0)
# ****: Karahan Tepe (ns: 0)
# ****: Moro I (sitio arqueológico) (ns: 0)
# ****: Murales de Afrasiab (ns: 0)
# ****: Nefrusy (ns: 0)
# ****: Piedras Gordas Tecate B.C. (ns: 0)
# ****: Poundbury Hill (ns: 0)
# ****: Tambo Viejo (ns: 0)
# ****: Tell (ns: 0)
# ****: Yacimiento arqueológico del Molino Manzánez (ns: 0)
# ****: Yacimiento de las Amoladeras (ns: 0)
# ****: Yacimientos neolíticos del Valle de Ambrona (ns: 0)
# ****: Zafar (ns: 0)
# ****: Categoría:Yacimientos arqueológicos por culturas (ns: 14)
# ****: Categoría:Yacimientos arqueológicos por país (ns: 14)
# ****: Categoría:Yacimientos arqueológicos por área cultural (ns: 14)
# ****: Categoría:Yacimientos arqueológicos por continente (ns: 14)
# ****: Categoría:Yacimientos arqueológicos por período (ns: 14)
# ****: Categoría:Ciudades de Mesopotamia (ns: 14)
# ****: Categoría:Crómlech (ns: 14)
# ****: Categoría:Cuevas prehistóricas (ns: 14)
# ****: Categoría:Montículos (ns: 14)
# ****: Categoría:Osarios (ns: 14)
# ****: Categoría:Yacimientos arqueológicos subacuáticos (ns: 14)
# ****: Categoría:Tesoros ocultos por época (ns: 14)
# ****: Categoría:Túmulos (ns: 14)
# **: Categoría:Ingeniería biomédica (ns: 14)
# ***: Ingeniería biomédica (ns: 0)
# ***: BioMedical Engineering OnLine (ns: 0)
# ***: E-NABLE (ns: 0)
# ***: Electromedicina (ns: 0)
# ***: Encapsulamiento celular (ns: 0)
# ***: Estimulación magnética transcraneana (ns: 0)
# ***: Exoesqueleto mecánico (ns: 0)
# ***: Ingeniería clínica (ns: 0)
# ***: Páncreas artificial (ns: 0)
# ***: Prótesis de retina Argus (ns: 0)
# ***: Prótesis valvular cardíaca (ns: 0)
# ***: The vOICe (ns: 0)
# ***: Categoría:Biomecánica (ns: 14)
# ****: Biomecánica (ns: 0)
# ****: Cadena cinética (Biomecánica) (ns: 0)
# ****: Criterio de lesión encefálica (ns: 0)
# ****: Gerontokinesiología (ns: 0)
# ****: Hidroesqueleto (ns: 0)
# ****: Kinesiología (ns: 0)
# ****: Ley cuadrático-cúbica (ns: 0)
# ****: Locomoción rotativa en sistemas vivos (ns: 0)
# ****: Nanobiomecánica (ns: 0)
# ****: Postura corporal neutra (ns: 0)
# ****: Pronosupinación del pie en carrera (ns: 0)
# ****: Reflejo vestíbulo emocional (ns: 0)
# ****: Suspensión mandibular (ns: 0)
# ****: Tejido blando (ns: 0)
# ****: Teoría constructal (ns: 0)
# ****: Categoría:Locomoción (ns: 14)
# ***: Categoría:Biónica (ns: 14)
# ****: Biónica (ns: 0)
# ****: Arquitectura biónica (ns: 0)
# ****: Biomimesis (ns: 0)
# ****: Lente de contacto biónica (ns: 0)
# ****: Computadora cognitiva (ns: 0)
# ****: Cybathlon (ns: 0)
# ****: Implante coclear (ns: 0)
# ****: Ingeniería biónica (ns: 0)
# ****: Prótesis de retina Argus (ns: 0)
# ****: Robótica bioinspirada (ns: 0)
# ****: Categoría:Exoesqueletos robóticos (ns: 14)
# ***: Categoría:Implantes (ns: 14)
# ****: Antena Cíborg (ns: 0)
# ****: Artroplastia de rodilla (ns: 0)
# ****: Artroplastia inversa de hombro (ns: 0)
# ****: Biocerámicas (ns: 0)
# ****: Catéter (ns: 0)
# ****: Catéter venoso central (ns: 0)
# ****: Cíborg (ns: 0)
# ****: Corazón artificial (ns: 0)
# ****: Dispositivo de asistencia ventricular (ns: 0)
# ****: Esfínter urinario artificial (ns: 0)
# ****: Estimulación del nervio vago (ns: 0)
# ****: Implante (medicina) (ns: 0)
# ****: Implante cerebral (ns: 0)
# ****: Implante coclear (ns: 0)
# ****: Implante de pene (ns: 0)
# ****: Implante dental (ns: 0)
# ****: Implante dental análoga a la raíz (ns: 0)
# ****: Implante subdérmico (ns: 0)
# ****: Implantes de pene en lesiones de la médula espinal (ns: 0)
# ****: Implantes de seno de polipropileno (ns: 0)
# ****: Injerto (medicina) (ns: 0)
# ****: Mamoplastia de aumento (ns: 0)
# ****: Neuroprótesis (ns: 0)
# ****: Órgano artificial (ns: 0)
# ****: Periimplantitis (ns: 0)
# ****: Prótesis de pene (ns: 0)
# ****: Prótesis de retina Argus (ns: 0)
# ****: Reemplazo de articulación (ns: 0)
# ****: Reemplazo de rodilla (ns: 0)
# ****: Stent bioabsorbible (ns: 0)
# ****: Sustitución de la válvula aórtica (ns: 0)
# ****: Categoría:Biónica (ns: 14)
# ***: Categoría:Prostética (ns: 14)
# ****: Prótesis (ns: 0)
# ****: Amortiguador reológico (ns: 0)
# ****: Artroplastia inversa de hombro (ns: 0)
# ****: Audífono (ns: 0)
# ****: Banco de Prótesis (ns: 0)
# ****: E-NABLE (ns: 0)
# ****: Esfínter urinario artificial (ns: 0)
# ****: Exoesqueleto mecánico (ns: 0)
# ****: Gluteoplastía (ns: 0)
# ****: Jaula expansible para fusión intercorporal (ns: 0)
# ****: Marcapasos cardíaco artificial (ns: 0)
# ****: Marcapasos compatible con resonancia magnética (ns: 0)
# ****: Órgano artificial (ns: 0)
# ****: Osteointegración (ns: 0)
# ****: Páncreas artificial (ns: 0)
# ****: Pata de palo (ns: 0)
# ****: Polímero electroactivo (ns: 0)
# ****: Prótesis de pene (ns: 0)
# ****: Prótesis impresas en 3D (ns: 0)
# ****: Prótesis ocular (ns: 0)
# ****: Prótesis ortopédica (ns: 0)
# ****: Prótesis visual (ns: 0)
# ****: Reemplazo de articulación (ns: 0)
# ****: Reemplazo de rodilla (ns: 0)
# ****: Sistema de bolsa de ostomía (ns: 0)
# ****: Sustitución de la válvula aórtica (ns: 0)
# ****: Válvula Bjork-Shiley (ns: 0)
# ****: Categoría:Exoesqueletos robóticos (ns: 14)
# ****: Categoría:Implantes (ns: 14)
# ****: Categoría:Prótesis dental (ns: 14)
# ***: Categoría:Revistas de ingeniería biomédica (ns: 14)
# ****: Annual Review of Biomedical Engineering (ns: 0)
# ****: BioMedical Engineering OnLine (ns: 0)
# ****: Biomedical Optics Express (ns: 0)
# ****: Journal of Applied Biomechanics (ns: 0)
# **: Categoría:Ingeniería de tejidos (ns: 14)
# ***: Ingeniería de tejidos (ns: 0)
# ***: Órgano en un chip (ns: 0)
# ***: Organoide (ns: 0)
# ***: Tissue Engineering and Regenerative Medicine International Society (ns: 0)
# ***: Categoría:Implantes (ns: 14)
# ****: Antena Cíborg (ns: 0)
# ****: Artroplastia de rodilla (ns: 0)
# ****: Artroplastia inversa de hombro (ns: 0)
# ****: Biocerámicas (ns: 0)
# ****: Catéter (ns: 0)
# ****: Catéter venoso central (ns: 0)
# ****: Cíborg (ns: 0)
# ****: Corazón artificial (ns: 0)
# ****: Dispositivo de asistencia ventricular (ns: 0)
# ****: Esfínter urinario artificial (ns: 0)
# ****: Estimulación del nervio vago (ns: 0)
# ****: Implante (medicina) (ns: 0)
# ****: Implante cerebral (ns: 0)
# ****: Implante coclear (ns: 0)
# ****: Implante de pene (ns: 0)
# ****: Implante dental (ns: 0)
# ****: Implante dental análoga a la raíz (ns: 0)
# ****: Implante subdérmico (ns: 0)
# ****: Implantes de pene en lesiones de la médula espinal (ns: 0)
# ****: Implantes de seno de polipropileno (ns: 0)
# ****: Injerto (medicina) (ns: 0)
# ****: Mamoplastia de aumento (ns: 0)
# ****: Neuroprótesis (ns: 0)
# ****: Órgano artificial (ns: 0)
# ****: Periimplantitis (ns: 0)
# ****: Prótesis de pene (ns: 0)
# ****: Prótesis de retina Argus (ns: 0)
# ****: Reemplazo de articulación (ns: 0)
# ****: Reemplazo de rodilla (ns: 0)
# ****: Stent bioabsorbible (ns: 0)
# ****: Sustitución de la válvula aórtica (ns: 0)
# ****: Categoría:Biónica (ns: 14)
# **: Categoría:Ingeniería genética (ns: 14)
# ***: Ingeniería genética (ns: 0)
# ***: ADN hachimoji (ns: 0)
# ***: ADN recombinante (ns: 0)
# ***: Agricultura molecular (ns: 0)
# ***: Animal modificado genéticamente (ns: 0)
# ***: Anti-CRISPR (ns: 0)
# ***: Arabidopsis thaliana (ns: 0)
# ***: Asunto Pusztai (ns: 0)
# ***: ATryn (ns: 0)
# ***: Biología DIY (ns: 0)
# ***: Cas9 (ns: 0)
# ***: Cas12a2 (ns: 0)
# ***: Chacasina (ns: 0)
# ***: Mary-Dell Chilton (ns: 0)
# ***: Cisgénesis (ns: 0)
# ***: Cpf1 (ns: 0)
# ***: CRISPR (ns: 0)
# ***: CRISPR/Cas (ns: 0)
# ***: CRISPR/Cpf1 (ns: 0)
# ***: Desextinción (ns: 0)
# ***: Edición de calidad (ns: 0)
# ***: Edición de genoma (ns: 0)
# ***: Edición del epigenoma (ns: 0)
# ***: Erradicación del sufrimiento (ns: 0)
# ***: Etiquetado de transposones (ns: 0)
# ***: Fago M13 (ns: 0)
# ***: GENCODE (ns: 0)
# ***: Genética dirigida (ns: 0)
# ***: Cosechas modificadas genéticamente (ns: 0)
# ***: Genpets (ns: 0)
# ***: Herramientas de diseño de CRISPR-Cas (ns: 0)
# ***: Historia de la ingeniería genética (ns: 0)
# ***: Ingeniería genética humana (ns: 0)
# ***: Insecto genéticamente modificado (ns: 0)
# ***: International Genetically Engineered Machine (ns: 0)
# ***: Introducción a la genética (ns: 0)
# ***: Lipofección (ns: 0)
# ***: Mendigos en España (ns: 0)
# ***: Mendigos y opulentos (ns: 0)
# ***: Metagenómica (ns: 0)
# ***: Metaproteómica (ns: 0)
# ***: Metatranscriptómica (ns: 0)
# ***: Motivo adyacente de protoespaciador (ns: 0)
# ***: Partenogénesis en mamíferos (ns: 0)
# ***: Patente biológica (ns: 0)
# ***: Péptidos de autoescisión 2A (ns: 0)
# ***: Planta genéticamente modificada (ns: 0)
# ***: Proteína recombinante (ns: 0)
# ***: Ratón humanizado (ns: 0)
# ***: Ratón knockout (ns: 0)
# ***: Ratón modificado genéticamente (ns: 0)
# ***: Ratón nude (ns: 0)
# ***: Sistemas de Información Genética Artificialmente Expandidos (ns: 0)
# ***: Somatotropina bovina (ns: 0)
# ***: Sonda molecular (ns: 0)
# ***: TALEN (ns: 0)
# ***: Técnicas de ingeniería genética (ns: 0)
# ***: Test de Ames (ns: 0)
# ***: Jacques Testart (ns: 0)
# ***: ARN CRISPR transactivante (ARNtracr) (ns: 0)
# ***: Transformación genética mediada por Agrobacterium rhizogenes (ns: 0)
# ***: Transgén (ns: 0)
# ***: Aaron Traywick (ns: 0)
# ***: Categoría:Clonación (ns: 14)
# ****: Clonación (ns: 0)
# ****: Anexo:Animales clonados (ns: 104)
# ****: Blastómero (ns: 0)
# ****: Blástula (ns: 0)
# ****: Keith Campbell (biólogo) (ns: 0)
# ****: Célula germinal (humana) (ns: 0)
# ****: Célula madre (ns: 0)
# ****: Célula madre pluripotente inducida (ns: 0)
# ****: Célula progenitora (ns: 0)
# ****: Célula somática (ns: 0)
# ****: Clon (ns: 0)
# ****: Clonación de especies extintas (ns: 0)
# ****: Clonación extensa (ns: 0)
# ****: Clonación humana (ns: 0)
# ****: Clonación posicional (ns: 0)
# ****: Cóntigo (ns: 0)
# ****: Cordón umbilical (ns: 0)
# ****: Cósmido (ns: 0)
# ****: Cromosoma artificial bacteriano (ns: 0)
# ****: Cromosoma artificial de levadura (ns: 0)
# ****: Electroporación (ns: 0)
# ****: Ética de la clonación (ns: 0)
# ****: Etiquetado de transposones (ns: 0)
# ****: Fagémido (ns: 0)
# ****: Gen (ns: 0)
# ****: Instituto Roslin (ns: 0)
# ****: Mórula (ns: 0)
# ****: Mycocepurus smithii (ns: 0)
# ****: Óvulo (ns: 0)
# ****: Transferencia nuclear celular (ns: 0)
# ****: Transferencia nuclear de células somáticas (ns: 0)
# ****: Vector de clonación (ns: 0)
# ****: Jean Weissenbach (ns: 0)
# ****: Ian Wilmut (ns: 0)
# ****: Categoría:Animales clonados (ns: 14)
# ****: Categoría:Clonación en la ficción (ns: 14)
# ***: Categoría:Enzimas de restricción (ns: 14)
# ****: Anexo:Endonucleasas homing de restricción (ns: 104)
# ****: Actividad star (ns: 0)
# ****: BamHI (ns: 0)
# ****: BglII (ns: 0)
# ****: EcoRI (ns: 0)
# ****: EcoRII (ns: 0)
# ****: EcoRV (ns: 0)
# ****: Endonucleasa homing (ns: 0)
# ****: Enzima de restricción (ns: 0)
# ****: FokI (ns: 0)
# ****: HaeIII (ns: 0)
# ****: HindII (ns: 0)
# ****: HindIII (ns: 0)
# ****: HpaII (ns: 0)
# ****: Isoesquizómero (ns: 0)
# ****: Nucleasas con dedos de zinc (ns: 0)
# ****: PstI (ns: 0)
# ****: SmaI (ns: 0)
# ****: Traslación de la muesca (ns: 0)
# ***: Categoría:Organismos modificados genéticamente (ns: 14)
# ****: Organismo genéticamente modificado (ns: 0)
# ****: ADN hachimoji (ns: 0)
# ****: Alimento transgénico (ns: 0)
# ****: ANDi (ns: 0)
# ****: Animal modificado genéticamente (ns: 0)
# ****: Bacteria modificada genéticamente (ns: 0)
# ****: Biolística (ns: 0)
# ****: Dinastía Pampa (ns: 0)
# ****: Injaz (ns: 0)
# ****: Insecto genéticamente modificado (ns: 0)
# ****: Knockdown de genes (ns: 0)
# ****: Ley de Bioseguridad de Organismos Genéticamente Modificados de México (ns: 0)
# ****: Mamíferos modificados genéticamente (ns: 0)
# ****: Mutagénesis (técnica de biología molecular) (ns: 0)
# ****: Nidera (ns: 0)
# ****: Oncoratón (ns: 0)
# ****: Oveja Dolly (ns: 0)
# ****: Oveja Polly (ns: 0)
# ****: Pampa (vaca) (ns: 0)
# ****: Pampa Mansa (ns: 0)
# ****: Peces transgénicos fluorescentes de acuario (ns: 0)
# ****: Peces modificados genéticamente (ns: 0)
# ****: Super p53 (ns: 0)
# ****: Syngenta (ns: 0)
# ****: Teorías conspirativas sobre los OMG (ns: 0)
# ****: Transformación genética mediada por Agrobacterium rhizogenes (ns: 0)
# ****: Virus modificado genéticamente (ns: 0)
# ****: Zhong Zhong y Hua Hua (ns: 0)
# ****: Categoría:Organismos modificados genéticamente en agricultura (ns: 14)
# ****: Categoría:Monsanto (ns: 14)
# ***: Categoría:Terapia génica (ns: 14)
# ****: Eteplirsén (ns: 0)
# ****: Etranacogene dezaparvovec (ns: 0)
# ****: Oligonucleótido antisentido (ns: 0)
# ****: Onasemnogene abeparvovec (ns: 0)
# ****: Receptor de antígeno quimérico (ns: 0)
# ****: Strímvelis (ns: 0)
# ****: Terapia de reemplazo mitocondrial (ns: 0)
# ****: Terapia génica (ns: 0)
# ****: Terapia génica antirretroviral (ns: 0)
# ****: Tisagenlecleucel (ns: 0)
# ****: ARN CRISPR transactivante (ARNtracr) (ns: 0)
# ****: Voretigene neparvovec (ns: 0)
# **: Categoría:Materiales biocompatibles (ns: 14)
# ***: Biocerámicas (ns: 0)
# ***: Biomaterial (ns: 0)
# ***: Material autorreparante (ns: 0)
# ***: Material biocompatible (ns: 0)
# ***: Péptidos anfifílicos (ns: 0)
# ***: Polietilenglicol (ns: 0)
# ***: Starlite (ns: 0)
# ***: Vitalio (ns: 0)
# ***: Categoría:Titanio (ns: 14)
# ****: Titanio (ns: 0)
# ****: Anexo:Isótopos de titanio (ns: 104)
# ****: Categoría:Compuestos de titanio (ns: 14)
# ****: Categoría:Minerales de titanio (ns: 14)
# *: Categoría:Biología (ns: 14)
# **: Biología (ns: 0)
# **: A genome- scale screen for synthetic drivers of T cell proliferation (ns: 0)
# **: Antropología biocultural (ns: 0)
# **: Usuario:Ayang0307/Taller (ns: 2)
# **: Biología cuantitativa (ns: 0)
# **: Bioproducción (ns: 0)
# **: Biosemiótica (ns: 0)
# **: Biosfera profunda (ns: 0)
# **: Buccinastrum deforme (ns: 0)
# **: Centroneuralia (ns: 0)
# **: Ciencias del karst (ns: 0)
# **: Clipnosis (ns: 0)
# **: Curvatura lumbar de 45 grados (ns: 0)
# **: Datos biológicos (ns: 0)
# **: Desarrollo postembrionario (ns: 0)
# **: EF-G (ns: 0)
# **: Endogenia (biología) (ns: 0)
# **: Endosexualidad (ns: 0)
# **: Evolución de la moralidad (ns: 0)
# **: Fenestral (ns: 0)
# **: Gen GALNS (ns: 0)
# **: Cristina Mittermeier (ns: 0)
# **: Hemotafonomía (ns: 0)
# **: Imagen de fluorescencias (ns: 0)
# **: Instituto para la Investigación Biológica de Israel (ns: 0)
# **: Material de Construcción Viviente (ns: 0)
# **: Microbiología (ns: 0)
# **: Leonora Milán (ns: 0)
# **: Multiómica (ns: 0)
# **: Nassariidae (ns: 0)
# **: Neontología (ns: 0)
# **: Noxa (ns: 0)
# **: Olimpiada Iberoamericana de Biología (ns: 0)
# **: Olimpiada Peruana de Biología (ns: 0)
# **: Péptido C (ns: 0)
# **: Péptidos de autoescisión 2A (ns: 0)
# **: Permutación circular en proteínas (ns: 0)
# **: Principales características de los seres vivos (ns: 0)
# **: Principio de los subsistemas de conjugados por V. Geodakian (ns: 0)
# **: Proyecto Web del Árbol de la vida (ns: 0)
# **: Putrefacción (ns: 0)
# **: Q10 (coeficiente de temperatura) (ns: 0)
# **: Química forense (ns: 0)
# **: Sexado (ns: 0)
# **: Sintrofía (ns: 0)
# **: Sistema biológico (ns: 0)
# **: Teleología en biología (ns: 0)
# **: Termodinámica biológica (ns: 0)
# **: Thanatosdrakon amaru (ns: 0)
# **: Transición epitelio-mesénquima (ns: 0)
# **: Vitaminas liposolubles (ns: 0)
# **: Categoría:Biólogos (ns: 14)
# ***: Biólogo (ns: 0)
# ***: Rie de Boois (ns: 0)
# ***: Ivan Erill (ns: 0)
# ***: Michael Eisen (ns: 0)
# ***: René Ngongo (ns: 0)
# ***: Durk Pearson (ns: 0)
# ***: Robert E. Hueter (ns: 0)
# ***: Diara Rocha (ns: 0)
# ***: Steven M. Stanley (ns: 0)
# ***: Ana María Viñas Díaz (ns: 0)
# ***: Jill Yager (ns: 0)
# ***: Categoría:Biólogas (ns: 14)
# ****: Geneviève Almouzni (ns: 0)
# ****: Karla Aparicio (ns: 0)
# ****: Emily Arnesen (ns: 0)
# ****: Arita Baaijens (ns: 0)
# ****: Yasmine Belkaid (ns: 0)
# ****: Idelisa Bonnelly (ns: 0)
# ****: Ana Colovic Lesoska (ns: 0)
# ****: Valerie Todd Davies (ns: 0)
# ****: Anne Dejean-Assémat (ns: 0)
# ****: Sandra Myrna Díaz (ns: 0)
# ****: Effa Funk Muhse (ns: 0)
# ****: Alice Embleton (ns: 0)
# ****: Eunice Enríquez (ns: 0)
# ****: Elena de Galantha (ns: 0)
# ****: Janet Gibson (ns: 0)
# ****: Olga Guramishvili-Nikoladze (ns: 0)
# ****: María Luisa Izaguirre (ns: 0)
# ****: Aban Marker Kabraji (ns: 0)
# ****: Paula Kahumbu (ns: 0)
# ****: Janet Kelso (ns: 0)
# ****: Eva Klein (ns: 0)
# ****: Yvonne Kranz-Baltensperger (ns: 0)
# ****: Titia de Lange (ns: 0)
# ****: Los Ángeles de Leakey (ns: 0)
# ****: Beronda Montgomery (ns: 0)
# ****: Indira Nath (ns: 0)
# ****: Liseth Pérez Alvarado (ns: 0)
# ****: Biljana Plavšić (ns: 0)
# ****: María Concepción Rodríguez de la Cruz (ns: 0)
# ****: Zehra Sayers (ns: 0)
# ****: Lubna Tahtamouni (ns: 0)
# ****: Anna Thynne (ns: 0)
# ****: Brigitta I. van Tussenbroek (ns: 0)
# ****: Ximena Vélez Liendo (ns: 0)
# ****: Loles Vives (ns: 0)
# ****: Categoría:Biólogas por país (ns: 14)
# ****: Categoría:Biólogas marinas (ns: 14)
# ****: Categoría:Botánicas (ns: 14)
# ****: Categoría:Micólogas (ns: 14)
# ****: Categoría:Virólogas (ns: 14)
# ***: Categoría:Biólogos por siglo (ns: 14)
# ****: Categoría:Biólogos del siglo IX (ns: 14)
# ****: Categoría:Biólogos del siglo X (ns: 14)
# ****: Categoría:Biólogos del siglo XI (ns: 14)
# ****: Categoría:Biólogos del siglo XII (ns: 14)
# ****: Categoría:Biólogos del siglo XIII (ns: 14)
# ****: Categoría:Biólogos del siglo XIV (ns: 14)
# ****: Categoría:Biólogos del siglo XV (ns: 14)
# ****: Categoría:Biólogos del siglo XVI (ns: 14)
# ****: Categoría:Biólogos del siglo XVII (ns: 14)
# ****: Categoría:Biólogos del siglo XVIII (ns: 14)
# ****: Categoría:Biólogos del siglo XIX (ns: 14)
# ****: Categoría:Biólogos del siglo XX (ns: 14)
# ****: Categoría:Biólogos del siglo XXI (ns: 14)
# ****: Categoría:Biólogos de Alemania por siglo (ns: 14)
# ****: Categoría:Botánicos por siglo (ns: 14)
# ****: Categoría:Biólogos de España por siglo (ns: 14)
# ****: Categoría:Biólogos de Estados Unidos por siglo (ns: 14)
# ****: Categoría:Biólogos de Francia por siglo (ns: 14)
# ****: Categoría:Biólogos de India por siglo (ns: 14)
# ****: Categoría:Biólogos de Italia por siglo (ns: 14)
# ****: Categoría:Biólogos de los Países Bajos por siglo (ns: 14)
# ****: Categoría:Biólogos del Reino Unido por siglo (ns: 14)
# ****: Categoría:Biólogos de Suecia por siglo (ns: 14)
# ****: Categoría:Zoólogos por siglo (ns: 14)
# ***: Categoría:Biólogos por disciplina (ns: 14)
# ****: Narcisa Martínez (ns: 0)
# ****: Categoría:Anatomistas (ns: 14)
# ****: Categoría:Astrobiólogos (ns: 14)
# ****: Categoría:Bioestadísticos (ns: 14)
# ****: Categoría:Biofísicos (ns: 14)
# ****: Categoría:Biogeógrafos (ns: 14)
# ****: Categoría:Bioinformáticos (ns: 14)
# ****: Categoría:Biólogos del desarrollo (ns: 14)
# ****: Categoría:Biólogos marinos (ns: 14)
# ****: Categoría:Biólogos moleculares (ns: 14)
# ****: Categoría:Bioquímicos (ns: 14)
# ****: Categoría:Biotecnólogos (ns: 14)
# ****: Categoría:Botánicos (ns: 14)
# ****: Categoría:Embriólogos (ns: 14)
# ****: Categoría:Etnobiólogos (ns: 14)
# ****: Categoría:Biólogos evolucionistas (ns: 14)
# ****: Categoría:Fisiólogos (ns: 14)
# ****: Categoría:Genetistas (ns: 14)
# ****: Categoría:Limnólogos (ns: 14)
# ****: Categoría:Microbiólogos (ns: 14)
# ****: Categoría:Neurobiólogos (ns: 14)
# ****: Categoría:Paleontólogos (ns: 14)
# ****: Categoría:Palinólogos (ns: 14)
# ****: Categoría:Planctólogos (ns: 14)
# ****: Categoría:Taxónomos (ns: 14)
# ****: Categoría:Zoólogos (ns: 14)
# ***: Categoría:Biólogos por país (ns: 14)
# ****: Petre Mihai Bănărescu (ns: 0)
# ****: Categoría:Anatomistas por país (ns: 14)
# ****: Categoría:Botánicos por país (ns: 14)
# ****: Categoría:Fisiólogos por país (ns: 14)
# ****: Categoría:Micólogos por país (ns: 14)
# ****: Categoría:Patólogos por país (ns: 14)
# ****: Categoría:Paleontólogos por país (ns: 14)
# ****: Categoría:Zoólogos por país (ns: 14)
# ****: Categoría:Biólogos de Afganistán (ns: 14)
# ****: Categoría:Biólogos de Albania (ns: 14)
# ****: Categoría:Biólogos de Alemania (ns: 14)
# ****: Categoría:Biólogos de Angola (ns: 14)
# ****: Categoría:Biólogos de Argelia (ns: 14)
# ****: Categoría:Biólogos de Argentina (ns: 14)
# ****: Categoría:Biólogos de Armenia (ns: 14)
# ****: Categoría:Biólogos de Australia (ns: 14)
# ****: Categoría:Biólogos de Austria (ns: 14)
# ****: Categoría:Biólogos de Azerbaiyán (ns: 14)
# ****: Categoría:Biólogos de Bangladés (ns: 14)
# ****: Categoría:Biólogos de Bélgica (ns: 14)
# ****: Categoría:Biólogos de Bielorrusia (ns: 14)
# ****: Categoría:Biólogos de Burkina Faso (ns: 14)
# ****: Categoría:Biólogos de Birmania (ns: 14)
# ****: Categoría:Biólogos de Bolivia (ns: 14)
# ****: Categoría:Biólogos de Bosnia y Herzegovina (ns: 14)
# ****: Categoría:Biólogos de Brasil (ns: 14)
# ****: Categoría:Biólogos de Bulgaria (ns: 14)
# ****: Categoría:Biólogos de Camboya (ns: 14)
# ****: Categoría:Biólogos de Camerún (ns: 14)
# ****: Categoría:Biólogos de Canadá (ns: 14)
# ****: Categoría:Biólogos de Chile (ns: 14)
# ****: Categoría:Biólogos de China (ns: 14)
# ****: Categoría:Biólogos de Chipre (ns: 14)
# ****: Categoría:Biólogos de Colombia (ns: 14)
# ****: Categoría:Biólogos de Corea del Sur (ns: 14)
# ****: Categoría:Biólogos de Costa de Marfil (ns: 14)
# ****: Categoría:Biólogos de Costa Rica (ns: 14)
# ****: Categoría:Biólogos de Croacia (ns: 14)
# ****: Categoría:Biólogos de Cuba (ns: 14)
# ****: Categoría:Biólogos de Dinamarca (ns: 14)
# ****: Categoría:Biólogos de Ecuador (ns: 14)
# ****: Categoría:Biólogos de Egipto (ns: 14)
# ****: Categoría:Biólogos de Eslovaquia (ns: 14)
# ****: Categoría:Biólogos de Eslovenia (ns: 14)
# ****: Categoría:Biólogos de España (ns: 14)
# ****: Categoría:Biólogos de Estados Unidos (ns: 14)
# ****: Categoría:Biólogos de Estonia (ns: 14)
# ****: Categoría:Biólogos de Etiopía (ns: 14)
# ****: Categoría:Biólogos de Filipinas (ns: 14)
# ****: Categoría:Biólogos de Finlandia (ns: 14)
# ****: Categoría:Biólogos de Francia (ns: 14)
# ****: Categoría:Biólogos de Gales (ns: 14)
# ****: Categoría:Biólogos de Georgia (ns: 14)
# ****: Categoría:Biólogos de Ghana (ns: 14)
# ****: Categoría:Biólogos de Grecia (ns: 14)
# ****: Categoría:Biólogos de Guatemala (ns: 14)
# ****: Categoría:Biólogos de Honduras (ns: 14)
# ****: Categoría:Biólogos de Hungría (ns: 14)
# ****: Categoría:Biólogos de India (ns: 14)
# ****: Categoría:Biólogos de Indonesia (ns: 14)
# ****: Categoría:Biólogos de Irán (ns: 14)
# ****: Categoría:Biólogos de Irak (ns: 14)
# ****: Categoría:Biólogos de Irlanda (ns: 14)
# ****: Categoría:Biólogos de Islandia (ns: 14)
# ****: Categoría:Biólogos de Israel (ns: 14)
# ****: Categoría:Biólogos de Italia (ns: 14)
# ****: Categoría:Biólogos de Jamaica (ns: 14)
# ****: Categoría:Biólogos de Japón (ns: 14)
# ****: Categoría:Biólogos de Kenia (ns: 14)
# ****: Categoría:Biólogos de Lesoto (ns: 14)
# ****: Categoría:Biólogos de Letonia (ns: 14)
# ****: Categoría:Biólogos del Líbano (ns: 14)
# ****: Categoría:Biólogos de Libia (ns: 14)
# ****: Categoría:Biólogos de Lituania (ns: 14)
# ****: Categoría:Biólogos de Luxemburgo (ns: 14)
# ****: Categoría:Biólogos de Malasia (ns: 14)
# ****: Categoría:Biólogos de Mauritania (ns: 14)
# ****: Categoría:Biólogos de México (ns: 14)
# ****: Categoría:Biólogos de Mozambique (ns: 14)
# ****: Categoría:Biólogos de Namibia (ns: 14)
# ****: Categoría:Biólogos de Nicaragua (ns: 14)
# ****: Categoría:Biólogos de Noruega (ns: 14)
# ****: Categoría:Biólogos de Nueva Zelanda (ns: 14)
# ****: Categoría:Biólogos de los Países Bajos (ns: 14)
# ****: Categoría:Biólogos de Pakistán (ns: 14)
# ****: Categoría:Biólogos de Panamá (ns: 14)
# ****: Categoría:Biólogos de Paraguay (ns: 14)
# ****: Categoría:Biólogos de Perú (ns: 14)
# ****: Categoría:Biólogos de Polonia (ns: 14)
# ****: Categoría:Biólogos de Portugal (ns: 14)
# ****: Categoría:Biólogos de Puerto Rico (ns: 14)
# ****: Categoría:Biólogos del Reino Unido (ns: 14)
# ****: Categoría:Biólogos de la República Checa (ns: 14)
# ****: Categoría:Biólogos de la República del Congo (ns: 14)
# ****: Categoría:Biólogos de República Dominicana (ns: 14)
# ****: Categoría:Biólogos de Rumania (ns: 14)
# ****: Categoría:Biólogos de Rusia (ns: 14)
# ****: Categoría:Biólogos de Serbia (ns: 14)
# ****: Categoría:Biólogos de Somalia (ns: 14)
# ****: Categoría:Biólogos de Sri Lanka (ns: 14)
# ****: Categoría:Biólogos de Sudáfrica (ns: 14)
# ****: Categoría:Biólogos de Suecia (ns: 14)
# ****: Categoría:Biólogos de Suiza (ns: 14)
# ****: Categoría:Biólogos de Tailandia (ns: 14)
# ****: Categoría:Biólogos de Taiwán (ns: 14)
# ****: Categoría:Biólogos de Tayikistán (ns: 14)
# ****: Categoría:Biólogos de Turquía (ns: 14)
# ****: Categoría:Biólogos de Ucrania (ns: 14)
# ****: Categoría:Biólogos de Uganda (ns: 14)
# ****: Categoría:Biólogos de Uruguay (ns: 14)
# ****: Categoría:Biólogos de Uzbekistán (ns: 14)
# ****: Categoría:Biólogos de Venezuela (ns: 14)
# ****: Categoría:Biólogos de Vietnam (ns: 14)
# ***: Categoría:Biólogos ficticios (ns: 14)
# ****: Aldrich Killian (ns: 0)
# ****: Alec Holland (ns: 0)
# ****: Amo de las Marionetas (ns: 0)
# ****: Atomic Skull (ns: 0)
# ****: Caballero Negro (Nathan Garrett) (ns: 0)
# ****: Rubeus Hagrid (ns: 0)
# ****: Jotaro Kujo (ns: 0)
# ****: Lemuel Dorcas (personaje) (ns: 0)
# ****: Maelstrom (Marvel Comics) (ns: 0)
# ****: Man-Bat (ns: 0)
# ****: Mercy (Overwatch) (ns: 0)
# ****: Mister Hyde (cómic) (ns: 0)
# ****: Morbius (ns: 0)
# ****: Pájaro Burlón (ns: 0)
# ****: Paul Stamets (Star Trek) (ns: 0)
# ****: Rosa y Espina (ns: 0)
# ****: Señor Siniestro (ns: 0)
# ****: Stephen Shin (ns: 0)
# ****: Silvestre Tornasol (ns: 0)
# ****: Categoría:Bioquímicos ficticios (ns: 14)
# ***: Categoría:Curadores (ns: 14)
# ****: Chit Ko Ko (ns: 0)
# ****: Sandi Hilal (ns: 0)
# ****: Tha Hla (ns: 0)
# ****: Categoría:Curadores de Alemania (ns: 14)
# ****: Categoría:Archiveros (ns: 14)
# ****: Categoría:Curadores de Argentina (ns: 14)
# ****: Categoría:Curadores de Australia (ns: 14)
# ****: Categoría:Curadores de Austria (ns: 14)
# ****: Categoría:Curadores de Bélgica (ns: 14)
# ****: Categoría:Curadores de Brasil (ns: 14)
# ****: Categoría:Curadores de Camerún (ns: 14)
# ****: Categoría:Curadores de Canadá (ns: 14)
# ****: Categoría:Curadores de Chile (ns: 14)
# ****: Categoría:Curadores de China (ns: 14)
# ****: Categoría:Curadores de Colombia (ns: 14)
# ****: Categoría:Curadores de Costa de Marfil (ns: 14)
# ****: Categoría:Curadores de Costa Rica (ns: 14)
# ****: Categoría:Curadores de Cuba (ns: 14)
# ****: Categoría:Curadoras (ns: 14)
# ****: Categoría:Curadores de Dinamarca (ns: 14)
# ****: Categoría:Curadores de Ecuador (ns: 14)
# ****: Categoría:Curadores de Eslovaquia (ns: 14)
# ****: Categoría:Curadores de Eslovenia (ns: 14)
# ****: Categoría:Curadores de España (ns: 14)
# ****: Categoría:Curadores de Estados Unidos (ns: 14)
# ****: Categoría:Curadores de Finlandia (ns: 14)
# ****: Categoría:Curadores de Francia (ns: 14)
# ****: Categoría:Curadores de Grecia (ns: 14)
# ****: Categoría:Curadores de Hungría (ns: 14)
# ****: Categoría:Curadores de India (ns: 14)
# ****: Categoría:Curadores de Irlanda (ns: 14)
# ****: Categoría:Curadores de Israel (ns: 14)
# ****: Categoría:Curadores de Italia (ns: 14)
# ****: Categoría:Curadores de Madagascar (ns: 14)
# ****: Categoría:Curadores de México (ns: 14)
# ****: Categoría:Curadores de Nueva Zelanda (ns: 14)
# ****: Categoría:Curadores de los Países Bajos (ns: 14)
# ****: Categoría:Curadores de Panamá (ns: 14)
# ****: Categoría:Curadores de Perú (ns: 14)
# ****: Categoría:Curadores de Polonia (ns: 14)
# ****: Categoría:Curadores de Portugal (ns: 14)
# ****: Categoría:Curadores del Reino Unido (ns: 14)
# ****: Categoría:Curadores de la República Checa (ns: 14)
# ****: Categoría:Curadores de Rusia (ns: 14)
# ****: Categoría:Curadores de Sudáfrica (ns: 14)
# ****: Categoría:Curadores de Suecia (ns: 14)
# ****: Categoría:Curadores de Suiza (ns: 14)
# ****: Categoría:Curadores de Turquía (ns: 14)
# ****: Categoría:Curadores de Ucrania (ns: 14)
# ****: Categoría:Curadores de Uruguay (ns: 14)
# ****: Categoría:Curadores de Venezuela (ns: 14)
# **: Categoría:Portal:Biología (ns: 14)
# ***: Portal:Biología/Actualidad/Archivo (ns: 100)
# ***: Portal:Biología/cabezero (ns: 100)
# ***: Portal:Biología/Destacado (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/1 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/2 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/3 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/4 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/5 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/6 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/7 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/8 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/9 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/10 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/11 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/12 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/13 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/14 (ns: 100)
# ***: Portal:Biología/Destacado/Aleatorio/15 (ns: 100)
# ***: Portal:Biología/Destacado/Archivo (ns: 100)
# ***: Portal:Biología/Imagen (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/1 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/2 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/3 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/4 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/5 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/6 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/7 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/8 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/9 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/10 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/11 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/12 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/13 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/14 (ns: 100)
# ***: Portal:Biología/Imagen/Aleatorio/15 (ns: 100)
# ***: Portal:Biología/Imágenes/Archivo (ns: 100)
# ***: Portal:Biología/piedepagina (ns: 100)
# ***: Portal:Biología/Zona de pruebas (ns: 100)
# **: Categoría:Vida (ns: 14)
# ***: Vida (ns: 0)
# ***: Esperanza de vida (ns: 0)
# ***: Género de vida (ns: 0)
# ***: Historia de la vida cotidiana (ns: 0)
# ***: Inmortalidad (ns: 0)
# ***: Nacimiento (ns: 0)
# ***: Prolongación de la vida (ns: 0)
# ***: Quiralidad (ns: 0)
# ***: Sedula mater (ns: 0)
# ***: Sentido de la vida (ns: 0)
# ***: Ser vivo (ns: 0)
# ***: Sistema vivo (ns: 0)
# ***: Teoría del curso de vida (ns: 0)
# ***: Vida (desambiguación) (ns: 0)
# ***: Vida basada en carbono (ns: 0)
# ***: Vida sintética (ns: 0)
# ***: Vida útil (ns: 0)
# ***: Categoría:Ciencias de la vida (ns: 14)
# ****: Ciencias de la vida (ns: 0)
# ****: Euroliga de Ciencias de la Vida (ns: 0)
# ****: Categoría:Bioingeniería (ns: 14)
# ****: Categoría:Biología (ns: 14)
# ****: Categoría:Biotecnología (ns: 14)
# ****: Categoría:Genómica (ns: 14)
# ****: Categoría:Ingeniería biomédica (ns: 14)
# ****: Categoría:Proteómica (ns: 14)
# ****: Categoría:Ciencias de la salud (ns: 14)
# ***: Categoría:Filosofía de la vida (ns: 14)
# ****: Amor fati (ns: 0)
# ****: Autorreflexión humana (ns: 0)
# ****: Axiarquía (ns: 0)
# ****: Crisis existencial (ns: 0)
# ****: Estilo de vida (ns: 0)
# ****: Filosofía de la felicidad (ns: 0)
# ****: Filosofía del absurdo (ns: 0)
# ****: Libre albedrío (ns: 0)
# ****: Magnum in parvo: Una filosofía en compendio (ns: 0)
# ****: Orden de la Buena Muerte (ns: 0)
# ****: Pesimismo filosófico (ns: 0)
# ****: Racionalismo moral (ns: 0)
# ****: Religión de la humanidad (ns: 0)
# ****: Filosofía del suicidio (ns: 0)
# ****: Tanatofobia (ns: 0)
# ****: Tao (ns: 0)
# ****: Tri Hita Karana (ns: 0)
# ****: Visualización negativa (ns: 0)
# ****: Categoría:Filosofía del amor (ns: 14)
# ****: Categoría:Espiritualidad (ns: 14)
# ****: Categoría:Ética normativa (ns: 14)
# ****: Categoría:Existencialismo (ns: 14)
# ****: Categoría:Humanismo (ns: 14)
# ****: Categoría:Idealismo (ns: 14)
# ****: Categoría:Irreligión (ns: 14)
# ****: Categoría:Libre albedrío (ns: 14)
# ****: Categoría:Nihilismo (ns: 14)
# ***: Categoría:Formas hipotéticas de vida (ns: 14)
# ****: Cinetótrofo (ns: 0)
# ****: Formas propuestas de vida (ns: 0)
# ****: Nanobacteria (ns: 0)
# ****: Nanobio (ns: 0)
# ****: Vida extraterrestre (ns: 0)
# ****: Categoría:Acytota (ns: 14)
# ***: Categoría:Inmortalidad (ns: 14)
# ****: Inmortalidad (ns: 0)
# ****: Amrita (ns: 0)
# ****: Árbol de la vida (ns: 0)
# ****: Árbol de la vida (bíblico) (ns: 0)
# ****: El fin del envejecimiento (ns: 0)
# ****: Eterna juventud (ns: 0)
# ****: Eternidad (ns: 0)
# ****: Fénix (ns: 0)
# ****: Fuente de la juventud (ns: 0)
# ****: Aubrey de Grey (ns: 0)
# ****: Inmortalidad biológica (ns: 0)
# ****: Raymond Kurzweil (ns: 0)
# ****: Transferencia mental (ns: 0)
# ****: Transhumanismo (ns: 0)
# ****: Turritopsis dohrnii (ns: 0)
# ****: Turritopsis nutricula (ns: 0)
# ****: Vida después de la muerte (ns: 0)
# ****: Categoría:Inmortales (ns: 14)
# ****: Categoría:Inmortalidad en la ficción (ns: 14)
# ***: Categoría:Muerte (ns: 14)
# ****: Muerte (ns: 0)
# ****: Wikiproyecto:Muerte (ns: 102)
# ****: Análisis de la supervivencia (ns: 0)
# ****: Comunicación después de la muerte inducida (ns: 0)
# ****: Conciencia después de la muerte (ns: 0)
# ****: Muerte de Dios (ns: 0)
# ****: Doula del final de la vida (ns: 0)
# ****: Efecto cumpleaños (ns: 0)
# ****: Escala de Miedo a la Muerte de Collett Lester (ns: 0)
# ****: Eterna juventud (ns: 0)
# ****: Eutanasia (ns: 0)
# ****: Exceso de mortalidad (ns: 0)
# ****: Fauna cadavérica (ns: 0)
# ****: Filosofía del Cuidado de la Salud (ns: 0)
# ****: Kodokushi (ns: 0)
# ****: Limpieza sueca para la muerte (ns: 0)
# ****: Muerte asistida (ns: 0)
# ****: Muerte digna (ns: 0)
# ****: Muerte teórica de información (ns: 0)
# ****: Muerte triple (ns: 0)
# ****: Necrocapitalismo (ns: 0)
# ****: Necrónimo (ns: 0)
# ****: Necropolítica (ns: 0)
# ****: Putrefacción (ns: 0)
# ****: Robo de cuerpos (ns: 0)
# ****: Secreciones respiratorias terminales (ns: 0)
# ****: Senicidio (ns: 0)
# ****: Sociología de la muerte (ns: 0)
# ****: Tablas de mortalidad (ns: 0)
# ****: Tanatofobia (ns: 0)
# ****: Tanatosis (ns: 0)
# ****: Teoría del manejo del terror (ns: 0)
# ****: Theta nigrum (ns: 0)
# ****: Vida después de la muerte (ns: 0)
# ****: Categoría:Fallecidos (ns: 14)
# ****: Categoría:Muerte por continente (ns: 14)
# ****: Categoría:Muerte por país (ns: 14)
# ****: Categoría:Arqueología de la muerte (ns: 14)
# ****: Categoría:Aspectos culturales de la muerte (ns: 14)
# ****: Categoría:Aspectos legales de la muerte (ns: 14)
# ****: Categoría:Aspectos médicos de la muerte (ns: 14)
# ****: Categoría:Causas de muerte (ns: 14)
# ****: Categoría:Muerte en el deporte (ns: 14)
# ****: Categoría:Duelo (emoción) (ns: 14)
# ****: Categoría:Entes póstumos (ns: 14)
# ****: Categoría:Eutanasia (ns: 14)
# ****: Categoría:Experiencias cercanas a la muerte (ns: 14)
# ****: Categoría:Extinción (ns: 14)
# ****: Categoría:Muerte arbórea (ns: 14)
# ****: Categoría:Muerte celular (ns: 14)
# ****: Categoría:Muerte de animales (ns: 14)
# ****: Categoría:Muerte e infancia (ns: 14)
# ****: Categoría:Muerte y género (ns: 14)
# ****: Categoría:Necrofilia (ns: 14)
# ****: Categoría:Pena de muerte (ns: 14)
# ****: Categoría:Sacrificio (ns: 14)
# ****: Categoría:Teorías conspiratorias sobre la muerte (ns: 14)
# ****: Categoría:Viudez (ns: 14)
# ***: Categoría:Origen de la vida (ns: 14)
# ****: Abiogénesis (ns: 0)
# ****: Acelular (ns: 0)
# ****: Ácido peptidonucleico (ns: 0)
# ****: Akilia (ns: 0)
# ****: Analogía del relojero (ns: 0)
# ****: Autoensamblaje (ns: 0)
# ****: Biogénesis (ns: 0)
# ****: Bugonia (ns: 0)
# ****: Caldo primigenio (ns: 0)
# ****: Cinturón de rocas verdes de Isua (ns: 0)
# ****: Ciudad Perdida (campo hidrotermal) (ns: 0)
# ****: Coacervado (ns: 0)
# ****: Colina primigenia (ns: 0)
# ****: Coloide (ns: 0)
# ****: Conjunto autocatalítico (ns: 0)
# ****: Creacionismo (ns: 0)
# ****: Creacionismo de la Tierra joven (ns: 0)
# ****: Creacionismo de Tierra vieja (ns: 0)
# ****: Anexo:Cronología de la historia evolutiva de la vida (ns: 104)
# ****: Christian de Duve (ns: 0)
# ****: John Edmonstone (ns: 0)
# ****: Manfred Eigen (ns: 0)
# ****: Experimento de Miller y Urey (ns: 0)
# ****: Falacia de Hoyle (ns: 0)
# ****: Sidney W. Fox (ns: 0)
# ****: Generación espontánea (ns: 0)
# ****: John Burdon Sanderson Haldane (ns: 0)
# ****: Hipótesis de la Tierra especial (ns: 0)
# ****: Hipótesis del citoplasma fuera (ns: 0)
# ****: Hipótesis del mundo de ARN (ns: 0)
# ****: Hipótesis del mundo de HAP (ns: 0)
# ****: Stuart Alan Kauffman (ns: 0)
# ****: Jean-Baptiste Lamarck (ns: 0)
# ****: Anton van Leeuwenhoek (ns: 0)
# ****: Meteorito Murchison (ns: 0)
# ****: Monstruo de Spiegelman (ns: 0)
# ****: Aleksandr Oparin (ns: 0)
# ****: Leslie Orgel (ns: 0)
# ****: Juan Oró (ns: 0)
# ****: Panspermia (ns: 0)
# ****: Louis Pasteur (ns: 0)
# ****: Principio antrópico (ns: 0)
# ****: Protobionte (ns: 0)
# ****: Quiralidad (ns: 0)
# ****: Reacción de la formosa (ns: 0)
# ****: Francesco Redi (ns: 0)
# ****: Ribozima (ns: 0)
# ****: Selección natural (ns: 0)
# ****: Lazzaro Spallanzani (ns: 0)
# ****: Teoría de la síntesis abiótica (ns: 0)
# ****: Teoría del mundo de hierro-azufre (ns: 0)
# ****: Teoría quimiosintética (ns: 0)
# ****: Tioéster (ns: 0)
# ****: Tolina (ns: 0)
# ****: Transpermia (ns: 0)
# ****: Último antepasado común universal (ns: 0)
# ****: Usuario:Vani 95/Taller (ns: 2)
# ****: Vida extraterrestre (ns: 0)
# ****: Viroide (ns: 0)
# ****: Günter Wächtershäuser (ns: 0)
# ****: Categoría:Astrobiología (ns: 14)
# ***: Categoría:Prolongación de la vida (ns: 14)
# ****: Baopuzi (ns: 0)
# ****: José Luis Cordeiro (ns: 0)
# ****: Criónica (ns: 0)
# ****: Eterna juventud (ns: 0)
# ****: Inmortalidad (ns: 0)
# ****: Nicotinamida mononucleótida (ns: 0)
# ****: Premio Breakthrough en Ciencias de la Vida (ns: 0)
# ****: Prolongación de la vida (ns: 0)
# ****: Reloj epigenético (ns: 0)
# ****: Terapia con células madre (ns: 0)
# ****: Categoría:Criónica (ns: 14)
# ****: Categoría:Inmortalidad (ns: 14)
# ***: Categoría:Reproducción (ns: 14)
# ****: Adelfogamia (ns: 0)
# ****: Aislamiento geográfico (ns: 0)
# ****: Alternancia de generaciones (ns: 0)
# ****: Reproducción alternante (ns: 0)
# ****: Altricial (ns: 0)
# ****: Androconio (ns: 0)
# ****: Anteridio (ns: 0)
# ****: Anterozoide (ns: 0)
# ****: Apareamiento (ns: 0)
# ****: Autofecundación (ns: 0)
# ****: Bebé de diseño (ns: 0)
# ****: Biogénesis (ns: 0)
# ****: Biología reproductiva (ns: 0)
# ****: Cariogamia (ns: 0)
# ****: Castración química (ns: 0)
# ****: Ciclo biológico de vida (ns: 0)
# ****: Ciclo de vida haplodiplonte (ns: 0)
# ****: Ciclo replicativo de los virus (ns: 0)
# ****: Cópula (zoología) (ns: 0)
# ****: Corpúsculo polar (ns: 0)
# ****: Cuerpo fructífero (plasmodio) (ns: 0)
# ****: Desarrollo prenatal (ns: 0)
# ****: Descendencia (ns: 0)
# ****: Dimorfismo generacional (ns: 0)
# ****: Dimorfismo sexual (ns: 0)
# ****: Dioico (ns: 0)
# ****: Disgenesia (ns: 0)
# ****: Donación de esperma (ns: 0)
# ****: Donación de ovocitos (ns: 0)
# ****: Efecto Wallace (ns: 0)
# ****: Embrión (ns: 0)
# ****: Espermateca (ns: 0)
# ****: Espermatóforo (ns: 0)
# ****: Espermatozoide (ns: 0)
# ****: Espermiogénesis (ns: 0)
# ****: Esterilidad (ns: 0)
# ****: Esterilización forzada en los Estados Unidos (ns: 0)
# ****: Esterilización forzosa (ns: 0)
# ****: Esterilización ultravioleta (ns: 0)
# ****: Eugenesia liberal (ns: 0)
# ****: Fecundidad (ns: 0)
# ****: Femenino (ns: 0)
# ****: Fertilidad (ns: 0)
# ****: Feto (ns: 0)
# ****: Gametangio (ns: 0)
# ****: Gameto (ns: 0)
# ****: Gametocito (ns: 0)
# ****: Gametogénesis (ns: 0)
# ****: Gametogonia (ns: 0)
# ****: Gemelos semi idénticos (ns: 0)
# ****: Generaciones telescópicas (ns: 0)
# ****: Gestación (ns: 0)
# ****: Gonocorismo (ns: 0)
# ****: Hembra (ns: 0)
# ****: Hermafroditismo (ns: 0)
# ****: Heterocronía (ns: 0)
# ****: Heterogamia (ns: 0)
# ****: Hija (ns: 0)
# ****: Hipótesis del costo de la reproducción (ns: 0)
# ****: Ictioplancton (ns: 0)
# ****: Incubación (ns: 0)
# ****: Incubación bucal (ns: 0)
# ****: Inmunología de la reproducción (ns: 0)
# ****: Inseminación artificial (ns: 0)
# ****: Instituto Chileno de Medicina Reproductiva (ns: 0)
# ****: Interfertilidad (ns: 0)
# ****: La familia Kallikak (ns: 0)
# ****: Lecha (ns: 0)
# ****: Macho (ns: 0)
# ****: Masculino (ns: 0)
# ****: Microbiota uterina (ns: 0)
# ****: Microquimerismo (ns: 0)
# ****: Monocarpismo (ns: 0)
# ****: Nacimiento (ns: 0)
# ****: Nacimiento múltiple (ns: 0)
# ****: Oospora (ns: 0)
# ****: Ooteca (ns: 0)
# ****: Operación Manos a la Obra (ns: 0)
# ****: Ovogonia (ns: 0)
# ****: Ovoviviparidad (ns: 0)
# ****: Óvulo (ns: 0)
# ****: Partenote (ns: 0)
# ****: Polispermia (ns: 0)
# ****: Principio de Fisher (ns: 0)
# ****: Productos de la concepción (ns: 0)
# ****: Pronúcleo (ns: 0)
# ****: Proporciones sexuales (ns: 0)
# ****: Quimiotaxis en espermatozoides marinos (ns: 0)
# ****: Reacción acrosómica (ns: 0)
# ****: Reproducción (ns: 0)
# ****: Reproducción asistida (ns: 0)
# ****: Reproducción asistida en el cristianismo (ns: 0)
# ****: Reproducción asistida en el Islam (ns: 0)
# ****: Reproducción asistida en el judaísmo (ns: 0)
# ****: Reproducción sexual (ns: 0)
# ****: Salud reproductiva (ns: 0)
# ****: Semelparidad e iteroparidad (ns: 0)
# ****: Sexo (ns: 0)
# ****: Sin hijos por elección (ns: 0)
# ****: Spermbot (ns: 0)
# ****: Superfecundación (ns: 0)
# ****: Superfetación (ns: 0)
# ****: Teleomorfo (ns: 0)
# ****: Telitoquia (ns: 0)
# ****: Teoría de la evolución de las relaciones sexuales por V. Geodakian (ns: 0)
# ****: Categoría:Reproducción sexual (ns: 14)
# ****: Categoría:Clonación (ns: 14)
# ****: Categoría:Dispersión biológica (ns: 14)
# ****: Categoría:Eugenesia (ns: 14)
# ****: Categoría:Fertilidad (ns: 14)
# ****: Categoría:Mejoramiento genético (ns: 14)
# ****: Categoría:Reproducción animal (ns: 14)
# ****: Categoría:Reproducción asexual (ns: 14)
# ****: Categoría:Reproducción celular (ns: 14)
# ****: Categoría:Reproducción vegetal (ns: 14)
# ****: Categoría:Semen (ns: 14)
# ****: Categoría:Vientres de alquiler (ns: 14)
# ***: Categoría:Seres ficticios (ns: 14)
# ****: Nuggle (ns: 0)
# ****: Xenu (ns: 0)
# ****: Categoría:Seres fantásticos (ns: 14)
# ****: Categoría:Animales de ficción (ns: 14)
# ****: Categoría:Híbridos de ficción (ns: 14)
# ****: Categoría:Hongos ficticios (ns: 14)
# ****: Categoría:Humanos de ficción (ns: 14)
# ****: Categoría:Neopets (ns: 14)
# ****: Categoría:Parásitos ficticios (ns: 14)
# ****: Categoría:Personajes ficticios (ns: 14)
# ...
# ***: Plantilla:Clados superiores incluido Monilophyta para texto (ns: 10)
# ***: Plantilla:Dentición (ns: 10)
# ***: Plantilla:Dryopithecus en Europa (ns: 10)
# ***: Plantilla:Elementos nutricionales en la tabla periódica (ns: 10)
# ***: Plantilla:Ficha de familia de proteínas (ns: 10)
# ***: Plantilla:Ficha de receptor celular/Localización intracelular (ns: 10)
# ***: Plantilla:Fisiología (ns: 10)
# ***: Plantilla:Fisiología del sistema endocrino (ns: 10)
# ***: Plantilla:Fórmula dental (ns: 10)
# ***: Plantilla:Genética humana (ns: 10)
# ***: Plantilla:Hominoidea (ns: 10)
# ***: Plantilla:Microbioma Humano (ns: 10)
# ***: Plantilla:Neurona mapa (ns: 10)
# ***: Plantilla:PhylomapB (ns: 10)
# ***: Plantilla:Plaguicidas (ns: 10)
# ***: Plantilla:Reacción enzimática (ns: 10)
# ***: Plantilla:Reacción enzimática compleja (ns: 10)
# ***: Plantilla:Transporte de membrana (ns: 10)
# ***: Categoría:Wikipedia:Plantillas de estados de conservación de la UICN (ns: 14)
# ****: Plantilla:EC-CR (ns: 10)
# ****: Plantilla:EC-DD (ns: 10)
# ****: Plantilla:EC-EN (ns: 10)
# ****: Plantilla:EC-EW (ns: 10)
# ****: Plantilla:EC-EX (ns: 10)
# ****: Plantilla:EC-LC (ns: 10)
# ****: Plantilla:EC-NE (ns: 10)
# ****: Plantilla:EC-NT (ns: 10)
# ****: Plantilla:EC-VU (ns: 10)
# ***: Categoría:Wikipedia:Plantillas para obras de referencia de biología (ns: 14)
# ****: Plantilla:Amphibian Species of the World (ns: 10)
# ****: Plantilla:AntCat (ns: 10)
# ****: Plantilla:Anthos (ns: 10)
# ****: Plantilla:APNI (ns: 10)
# ****: Plantilla:Botánico (ns: 10)
# ****: Plantilla:Cita COL (ns: 10)
# ****: Plantilla:Flora of Australia Online (ns: 10)
# ****: Plantilla:FloraBase (ns: 10)
# ****: Plantilla:GBIF (ns: 10)
# ****: Plantilla:Cita Indexfungorum (ns: 10)
# ****: Plantilla:IndexFungorum (ns: 10)
# ****: Plantilla:IPNI (ns: 10)
# ****: Plantilla:IPNI autor (ns: 10)
# ****: Plantilla:ITIS (ns: 10)
# ****: Plantilla:IUCN (ns: 10)
# ****: Plantilla:Kew species (ns: 10)
# ****: Plantilla:Molina, 1782 (ns: 10)
# ****: Plantilla:MSW3 (ns: 10)
# ****: Plantilla:MSW3 Artiodactyla (ns: 10)
# ****: Plantilla:MSW3 Gardner (ns: 10)
# ****: Plantilla:MSW3 Groves (ns: 10)
# ****: Plantilla:Cita NCBI (ns: 10)
# ****: Plantilla:NSW Flora Online (ns: 10)
# ****: Plantilla:RefPD (ns: 10)
# ****: Plantilla:ReptileDB género (ns: 10)
# ****: Categoría:Wikipedia:Plantillas de referencias a FishBase (ns: 14)
# ****: Categoría:Wikipedia:Plantillas para obras de referencia de aves (ns: 14)
# ***: Categoría:Wikipedia:Fichas de biología (ns: 14)
# ****: Plantilla:Ficha de animal (ns: 10)
# ****: Plantilla:Ficha de cromosoma (ns: 10)
# ****: Plantilla:Ficha de cultivar (ns: 10)
# ****: Plantilla:Ficha de variedad de uva (ns: 10)
# ****: Plantilla:Ficha de fósil (ns: 10)
# ****: Plantilla:Ficha de fungi (ns: 10)
# ****: Plantilla:Ficha de icnotaxón (ns: 10)
# ****: Plantilla:Ficha de proteína (ns: 10)
# ****: Plantilla:Ficha de raza (ns: 10)
# ****: Plantilla:Taxón (ns: 10)
# ****: Plantilla:Ficha de taxón (ns: 10)
# ****: Usuario:Poco a poco/Ficha de taxón (ns: 2)
# ****: Plantilla:Ficha de zoológico (ns: 10)
# ****: Categoría:Wikipedia:Fichas de medicina (ns: 14)
# ***: Categoría:Wikipedia:Plantillas de enlaces externos de biología (ns: 14)
# ****: Plantilla:AlgaeBase species (ns: 10)
# ****: Plantilla:Amphibian Species of the World (ns: 10)
# ****: Plantilla:Aves de Chile (ns: 10)
# ****: Plantilla:Avibase (ns: 10)
# ****: Plantilla:BHL page (ns: 10)
# ****: Plantilla:Botánico (ns: 10)
# ****: Plantilla:Catalogue of Life (ns: 10)
# ****: Plantilla:EOL (ns: 10)
# ****: Plantilla:Flora of Australia Online (ns: 10)
# ****: Plantilla:FloraBase (ns: 10)
# ****: Plantilla:GBIF (ns: 10)
# ****: Plantilla:IndexFungorum (ns: 10)
# ****: Plantilla:IPNI (ns: 10)
# ****: Plantilla:IPNI autor (ns: 10)
# ****: Plantilla:ITIS (ns: 10)
# ****: Plantilla:IUCN (ns: 10)
# ****: Plantilla:Kew species (ns: 10)
# ****: Plantilla:MSW3 (ns: 10)
# ****: Plantilla:MSW3 Gardner (ns: 10)
# ****: Plantilla:MSW3 Groves (ns: 10)
# ****: Plantilla:NRDB species (ns: 10)
# ****: Plantilla:NSW Flora Online (ns: 10)
# ****: Plantilla:PDBe (ns: 10)
# ****: Plantilla:Proteopedia (ns: 10)
# ****: Plantilla:ReptileDB género (ns: 10)
# ****: Categoría:Wikipedia:Plantillas de referencias a FishBase (ns: 14)
# ***: Categoría:Wikipedia:Plantillas de genética (ns: 14)
# ****: Plantilla:ADN-Y (ns: 10)
# ****: Plantilla:ADNmt (ns: 10)
# **: Categoría:Anexos:Biología (ns: 14)
# ***: Anexo:100 de las especies exóticas invasoras más dañinas del mundo (ns: 104)
# ***: Anexo:Aminoácidos (ns: 104)
# ***: Anexo:Biota de Chengjiang (ns: 104)
# ***: Anexo:Biota del esquisto de Burgess (ns: 104)
# ***: Anexo:Catálogo Español de Especies Exóticas Invasoras (ns: 104)
# ***: Anexo:Cronología de la alimentación humana (ns: 104)
# ***: Anexo:Disciplinas de la Biología (ns: 104)
# ***: Anexo:Endonucleasas homing de restricción (ns: 104)
# ***: Anexo:Especies extintas en la naturaleza según la UICN (ns: 104)
# ***: Anexo:Especies extintas por la actividad humana (ns: 104)
# ***: Anexo:Géneros de la biota de Ediacara (ns: 104)
# ***: Anexo:Genomas eucariotas secuenciados (ns: 104)
# ***: Anexo:Métodos de camuflaje (ns: 104)
# ***: Anexo:Lista negra preliminar de especies exóticas invasoras para España (ns: 104)
# ***: Anexo:Ninfálidos de la península ibérica y Baleares (ns: 104)
# ***: Anexo:Número de neuronas de los animales (ns: 104)
# ***: Anexo:Organismos semiacuáticos (ns: 104)
# ***: Panorama de la biología (ns: 0)
# ***: Anexo:Plantas que filtran el aire (ns: 104)
# ***: Anexo:Psicotrópicos (ns: 104)
# ***: Categoría:Anexos:Anatomía (ns: 14)
# ****: Anexo:Anatomía del corazón humano (ns: 104)
# ****: Anexo:Arterias del cuerpo humano (ns: 104)
# ****: Anexo:Articulaciones del cuerpo humano (ns: 104)
# ****: Anexo:Cavidad abdominopélvica (Anatomía humana) (ns: 104)
# ****: Anexo:Cavidad torácica (Anatomía humana) (ns: 104)
# ****: Anexo:Epónimos usados en anatomía humana (ns: 104)
# ****: Anexo:Esqueleto humano (ns: 104)
# ****: Anexo:Líneas anatómicas (ns: 104)
# ****: Anexo:Músculos del cuerpo humano (ns: 104)
# ****: Anexo:Músculos esqueléticos del cuerpo humano (ns: 104)
# ****: Nervio de Wrisberg (ns: 0)
# ****: Anexo:Órganos de los sentidos (Anatomía humana) (ns: 104)
# ****: Anexo:Partes del cuerpo humano (ns: 104)
# ****: Anexo:Piel y faneras (Anatomía humana) (ns: 104)
# ****: Anexo:Porción autonómica del sistema nervioso periférico (Anatomía humana) (ns: 104)
# ****: Anexo:Regiones del cuerpo humano (ns: 104)
# ****: Anexo:Sistema cardiovascular (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema digestivo (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema endocrino (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema esquelético (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema genital femenino (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema genital masculino (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema linfático (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema nervioso central (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema nervioso periférico (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema respiratorio (Anatomía humana) (ns: 104)
# ****: Anexo:Sistema urinario (Anatomía humana) (ns: 104)
# ****: Anexo:Términos anatómicos de localización (anatomía humana) (ns: 104)
# ****: Anexo:Venas del cuerpo humano (ns: 104)
# ***: Categoría:Anexos:Hongos (ns: 14)
# ****: Anexo:Especies de Agaricus (ns: 104)
# ****: Anexo:Especies de Amanita (ns: 104)
# ****: Anexo:Especies de Boletus (ns: 104)
# ****: Anexo:Especies de Lactarius (ns: 104)
# ****: Anexo:Especies de Pholiotina (ns: 104)
# ****: Anexo:Especies del género Cortinarius (ns: 104)
# ****: Anexo:Especies de Hebeloma (ns: 104)
# ****: Anexo:Hongos bioluminiscentes (ns: 104)
# ****: Anexo:Hongos de Chile (ns: 104)
# ****: Anexo:Hongos psilocibios (ns: 104)
# ****: Anexo:Especies de Psilocybe (ns: 104)
# ****: Anexo:Especies de Russula (ns: 104)
# ****: Anexo:Géneros de Tricholomataceae (ns: 104)
# ***: Categoría:Anexos:Biodiversidad por país (ns: 14)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       8 cat = agent_es.page("Category:Ciencias de la vida")
#       9 print("Category members: Category:Ciencias de la vida")
# ---> 12 print_categorymembers(cat.categorymembers, level=0, max_level=3)
#
# Cell In[4], line 5, in print_categorymembers(categorymembers, level, max_level)
#       3 print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
#       4 if c.ns == wikipediaapi.Namespace.CATEGORY and level < max_level:
# ----> 5     print_categorymembers(c.categorymembers, level=level + 1, max_level=max_level)
#
# Cell In[4], line 5, in print_categorymembers(categorymembers, level, max_level)
#       3 print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
#       4 if c.ns == wikipediaapi.Namespace.CATEGORY and level < max_level:
# ----> 5     print_categorymembers(c.categorymembers, level=level + 1, max_level=max_level)
#
# Cell In[4], line 5, in print_categorymembers(categorymembers, level, max_level)
#       3 print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
#       4 if c.ns == wikipediaapi.Namespace.CATEGORY and level < max_level:
# ----> 5     print_categorymembers(c.categorymembers, level=level + 1, max_level=max_level)
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:1059, in WikipediaPage.categorymembers(self)
#    1048 """
#    1049 Returns all pages belonging to the current category.
#    1050
#    (...)
#    1056 :return: :class:`PagesDict`
#    1057 """
#    1058 if not self._called["categorymembers"]:
# -> 1059     self._fetch("categorymembers")
#    1060 return self._categorymembers
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:1064, in WikipediaPage._fetch(self, call)
#    1062 def _fetch(self, call) -> "WikipediaPage":
#    1063     """Fetches some data?."""
# -> 1064     getattr(self.wiki, call)(self)
#    1065     self._called[call] = True
#    1066     return self
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:508, in Wikipedia.categorymembers(self, page, **kwargs)
#     505 used_params = kwargs
#     506 used_params.update(params)
# --> 508 raw = self._query(page, used_params)
#     510 self._common_attributes(raw["query"], page)
#     511 v = raw["query"]
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:528, in Wikipedia._query(self, page, params)
#     526 params["format"] = "json"
#     527 params["redirects"] = 1
# --> 528 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     529 return r.json()
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/GitHub/wikipedia-bio-pretrain/.venv/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import wikipediaapi
import concurrent.futures
from tqdm import tqdm

def get_subcategories(category, depth, max_depth):
    if depth > max_depth:
        return []
    subcategories = []
    for subcategory in category.categorymembers.values():
        if subcategory.ns == wikipediaapi.Namespace.CATEGORY:
            subcategories.append(subcategory)
            subcategories.extend(get_subcategories(subcategory, depth + 1, max_depth))
    return subcategories

def get_articles(category, articles_set):
    articles = []
    for member in category.categorymembers.values():
        if member.ns == wikipediaapi.Namespace.MAIN:
            if member.title not in articles_set:
                articles.append(member)
                articles_set.add(member.title)
    return articles

def fetch_subcategories(subcategory):
    return get_subcategories(subcategory, 1, max_depth)

def fetch_articles(subcategory):
    return get_articles(subcategory, articles_set)

wiki_wiki = wikipediaapi.Wikipedia("papapa", 'es')

category_name = "Categoría:Ciencias de la vida"
category = wiki_wiki.page(category_name)

if not category.exists():
    print(f"Category '{category_name}' does not exist.")

max_depth = 5
print(f"Get subcategories from Category:{category}")

# Using ThreadPoolExecutor to parallelize the fetching of subcategories
with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [executor.submit(fetch_subcategories, subcategory) for subcategory in category.categorymembers.values() if subcategory.ns == wikipediaapi.Namespace.CATEGORY]
    
    subcategories = []
    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures)):
        subcategories.extend(future.result())

print(f"Get articles from Category:{category}")
articles_set = set()
articles = get_articles(category, articles_set)

print(f"Subcategories: {len(subcategories)}")
print(f"Articles: {len(articles)}")

# Using ThreadPoolExecutor to parallelize the fetching of articles from subcategories
with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [executor.submit(fetch_articles, subcategory) for subcategory in subcategories]

    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures)):
        articles.extend(future.result())
# Out:
# Get subcategories from Category:Categoría:Ciencias de la vida (id: 4591756, ns: 14)
# 100%|██████████| 7/7 [49:10<00:00, 421.50s/it]
# Get articles from Category:Categoría:Ciencias de la vida (id: 4591756, ns: 14)
# Subcategories: 66325
# Articles: 2
# 100%|██████████| 66325/66325 [15:24<00:00, 71.74it/s]

# %%
import concurrent.futures
from tqdm import tqdm

# Assuming the definitions for get_subcategories and get_articles are already available

max_depth = 5
print(f"Get subcategories from Category:{category}")
subcategories = get_subcategories(category, 4, max_depth)

print(f"Get articles from Category:{category}")
articles_set = set()
articles = get_articles(category, articles_set)

print(f"Subcategories: {len(subcategories)}")
print(f"Articles: {len(articles)}")

def fetch_articles(subcategory):
    return get_articles(subcategory, articles_set)

# Using ThreadPoolExecutor to parallelize the fetching of articles from subcategories
with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [executor.submit(fetch_articles, subcategory) for subcategory in subcategories]

    for future in tqdm(concurrent.futures.as_completed(futures), total=len(futures)):
        articles.extend(future.result())
# Out:
# Get subcategories from Category:Categoría:Ciencias de la vida (id: 4591756, ns: 14)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 8
#       6 max_depth = 5
#       7 print(f"Get subcategories from Category:{category}")
# ----> 8 subcategories = get_subcategories(category, 3, max_depth)
#      10 print(f"Get articles from Category:{category}")
#      11 articles_set = set()
#
# Cell In[60], line 10, in get_subcategories(category, depth, max_depth)
#       8     if subcategory.ns == wikipediaapi.Namespace.CATEGORY:
#       9         subcategories.append(subcategory)
# ---> 10         subcategories.extend(get_subcategories(subcategory, depth + 1, max_depth))
#      11 return subcategories
#
# Cell In[60], line 10, in get_subcategories(category, depth, max_depth)
#       8     if subcategory.ns == wikipediaapi.Namespace.CATEGORY:
#       9         subcategories.append(subcategory)
# ---> 10         subcategories.extend(get_subcategories(subcategory, depth + 1, max_depth))
#      11 return subcategories
#
# Cell In[60], line 7, in get_subcategories(category, depth, max_depth)
#       5     return []
#       6 subcategories = []
# ----> 7 for subcategory in category.categorymembers.values():
#       8     if subcategory.ns == wikipediaapi.Namespace.CATEGORY:
#       9         subcategories.append(subcategory)
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:1059, in WikipediaPage.categorymembers(self)
#    1048 """
#    1049 Returns all pages belonging to the current category.
#    1050
#    (...)
#    1056 :return: :class:`PagesDict`
#    1057 """
#    1058 if not self._called["categorymembers"]:
# -> 1059     self._fetch("categorymembers")
#    1060 return self._categorymembers
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:1064, in WikipediaPage._fetch(self, call)
#    1062 def _fetch(self, call) -> "WikipediaPage":
#    1063     """Fetches some data?."""
# -> 1064     getattr(self.wiki, call)(self)
#    1065     self._called[call] = True
#    1066     return self
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:508, in Wikipedia.categorymembers(self, page, **kwargs)
#     505 used_params = kwargs
#     506 used_params.update(params)
# --> 508 raw = self._query(page, used_params)
#     510 self._common_attributes(raw["query"], page)
#     511 v = raw["query"]
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/wikipediaapi/__init__.py:528, in Wikipedia._query(self, page, params)
#     526 params["format"] = "json"
#     527 params["redirects"] = 1
# --> 528 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     529 return r.json()
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/GitHub/biowikipedia-dbpedia/.venv/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Out:
# [Ciencias de la vida (id: ??, ns: 0),
#  Euroliga de Ciencias de la Vida (id: ??, ns: 0),
#  Agricultura molecular (id: ??, ns: 0),
#  Amortiguador reológico (id: ??, ns: 0),
#  Bioastronáutica (id: ??, ns: 0),
#  Biocibernética (id: ??, ns: 0),
#  Biocompatibilidad (id: ??, ns: 0),
#  Biofabricación (id: ??, ns: 0),
#  Bioimpresión 3D (id: ??, ns: 0),
#  Bioinformática (id: ??, ns: 0),
#  BIOMED (id: ??, ns: 0),
#  Biorreactor (id: ??, ns: 0),
#  Cerámica piezoeléctrica (id: ??, ns: 0),
#  E-NABLE (id: ??, ns: 0),
#  Edición de calidad (id: ??, ns: 0),
#  Fed-batch (id: ??, ns: 0),
#  Gene targeting (id: ??, ns: 0),
#  Hígado artificial (id: ??, ns: 0),
#  Ingeniería biológica (id: ??, ns: 0),
#  Ingeniería biónica (id: ??, ns: 0),
#  Ingeniería de tejidos (id: ??, ns: 0),
#  Ingeniería genética humana (id: ??, ns: 0),
#  Instituto de Investigación Biomédica de Lérida (id: ??, ns: 0),
#  Instituto de Investigación Biomédica (id: ??, ns: 0),
#  Instituto Maimónides de Investigación Biomédica de Córdoba (id: ??, ns: 0),
#  Instituto Nacional de Bioinformática (id: ??, ns: 0),
#  Material biocompatible (id: ??, ns: 0),
#  TALEN (id: ??, ns: 0),
#  Transformación genética mediada por Agrobacterium rhizogenes (id: ??, ns: 0),
#  Rebecca R. Richards-Kortum (id: ??, ns: 0),
#  Rober Malkin (id: ??, ns: 0),
#  Carolina Serrano Larrea (id: ??, ns: 0),
#  Biología sintética (id: ??, ns: 0),
#  Atoxilo (id: ??, ns: 0),
#  Carne cultivada (id: ??, ns: 0),
#  Célula artificial (id: ??, ns: 0),
#  Circuito biológico sintético (id: ??, ns: 0),
#  Cirugía sin sangre (id: ??, ns: 0),
#  Fotografía bacteriana (id: ??, ns: 0),
#  International Genetically Engineered Machine (id: ??, ns: 0),
#  Island Conservation (id: ??, ns: 0),
#  Mycoplasma laboratorium (id: ??, ns: 0),
#  Organoide cerebral (id: ??, ns: 0),
#  Piel artificial (id: ??, ns: 0),
#  Represilador (id: ??, ns: 0),
#  Revive & Restore (id: ??, ns: 0),
#  Sustituto sanguíneo (id: ??, ns: 0),
#  Vida sintética (id: ??, ns: 0),
#  Virología sintética (id: ??, ns: 0),
#  Xenobot (id: ??, ns: 0),
#  Biomecánica (id: ??, ns: 0),
#  Cadena cinética (Biomecánica) (id: ??, ns: 0),
#  Criterio de lesión encefálica (id: ??, ns: 0),
#  Gerontokinesiología (id: ??, ns: 0),
#  Hidroesqueleto (id: ??, ns: 0),
#  Kinesiología (id: ??, ns: 0),
#  Ley cuadrático-cúbica (id: ??, ns: 0),
#  Locomoción rotativa en sistemas vivos (id: ??, ns: 0),
#  Nanobiomecánica (id: ??, ns: 0),
#  Postura corporal neutra (id: ??, ns: 0),
#  Pronosupinación del pie en carrera (id: ??, ns: 0),
#  Reflejo vestíbulo emocional (id: ??, ns: 0),
#  Suspensión mandibular (id: ??, ns: 0),
#  Tejido blando (id: ??, ns: 0),
#  Teoría constructal (id: ??, ns: 0),
#  9,10-ditioantraceno (id: ??, ns: 0),
#  Análisis de la marcha (id: ??, ns: 0),
#  Andadura (id: ??, ns: 0),
#  Bipedestación (id: ??, ns: 0),
#  Braquiación (id: ??, ns: 0),
#  Comportamiento suspensorio (id: ??, ns: 0),
#  Corredor (biología) (id: ??, ns: 0),
#  De puntillas (id: ??, ns: 0),
#  Digitígrado (id: ??, ns: 0),
#  Durotaxis (id: ??, ns: 0),
#  El movimiento de los animales (id: ??, ns: 0),
#  Física del vuelo (id: ??, ns: 0),
#  Galope (id: ??, ns: 0),
#  Galope de doble suspensión (id: ??, ns: 0),
#  Haptotaxis (id: ??, ns: 0),
#  Locomoción aérea (id: ??, ns: 0),
#  Locomoción animal (id: ??, ns: 0),
#  Locomoción terrestre (id: ??, ns: 0),
#  Mimetismo locomotor (id: ??, ns: 0),
#  Pezuña (id: ??, ns: 0),
#  Plantígrado (id: ??, ns: 0),
#  Salto (locomoción) (id: ??, ns: 0),
#  Salto de rebote (id: ??, ns: 0),
#  Sesilidad (biología) (id: ??, ns: 0),
#  Ungulígrado (id: ??, ns: 0),
#  Hábitat humano (id: ??, ns: 0),
#  Bastle house (id: ??, ns: 0),
#  Boma (recinto) (id: ??, ns: 0),
#  Complejo (arquitectura) (id: ??, ns: 0),
#  Cortiço (id: ??, ns: 0),
#  Dominio (territorio) (id: ??, ns: 0),
#  Edificio autónomo (id: ??, ns: 0),
#  Finca (id: ??, ns: 0),
#  Finca rústica (id: ??, ns: 0),
#  Granja agrícola (id: ??, ns: 0),
#  Hábitat espacial (id: ??, ns: 0),
#  Kraal (id: ??, ns: 0),
#  Mesohábitat (id: ??, ns: 0),
#  Mouza (id: ??, ns: 0),
#  Pueblo pesquero (id: ??, ns: 0),
#  Yaodong (id: ??, ns: 0),
#  Comunidad intencional (id: ??, ns: 0),
#  Awra Amba (id: ??, ns: 0),
#  Brook Farm (id: ??, ns: 0),
#  Colonia Cecilia (id: ??, ns: 0),
#  Comuna (id: ??, ns: 0),
#  Comunidades de El Arca (Lanza del Vasto) (id: ??, ns: 0),
#  Comunidades utópicas (id: ??, ns: 0),
#  Covivienda (id: ??, ns: 0),
#  Ecoaldea (id: ??, ns: 0),
#  Monacato (id: ??, ns: 0),
#  Moshav (id: ??, ns: 0),
#  Tamera (id: ??, ns: 0),
#  Walden dos (id: ??, ns: 0),
#  ZEGG (id: ??, ns: 0),
#  Zona Autónoma de Capitol Hill (id: ??, ns: 0),
#  Propiedad imperial (Antigua Roma) (id: ??, ns: 0),
#  Villa rustica (id: ??, ns: 0),
#  Piscina lunar (id: ??, ns: 0),
#  Hospedaje (viaje) (id: ??, ns: 0),
#  Museo Rosa Bonheur (id: ??, ns: 0),
#  Yacimiento arqueológico (id: ??, ns: 0),
#  Adloun (id: ??, ns: 0),
#  Aigyr-Zhal 2 (id: ??, ns: 0),
#  Arte rupestre en México (id: ??, ns: 0),
#  Bajada Km 57 (id: ??, ns: 0),
#  Barcos de Salme (id: ??, ns: 0),
#  Cañón de las Tinaja Cucapá (id: ??, ns: 0),
#  Castro de la Loma (id: ??, ns: 0),
#  Cuddie Springs (id: ??, ns: 0),
#  Cueva del Guerrero (id: ??, ns: 0),
#  Cultura de la daga de bronce (id: ??, ns: 0),
#  Dolmen de Santa Inés (id: ??, ns: 0),
#  El Vallecito (Baja California) (id: ??, ns: 0),
#  Expolio arqueológico y artístico (id: ??, ns: 0),
#  Hipogeo de Torre del Ram (id: ??, ns: 0),
#  Huaca Casa Rosada (id: ??, ns: 0),
#  Isla Nipisat (id: ??, ns: 0),
#  Karahan Tepe (id: ??, ns: 0),
#  Moro I (sitio arqueológico) (id: ??, ns: 0),
#  Murales de Afrasiab (id: ??, ns: 0),
#  Nefrusy (id: ??, ns: 0),
#  Piedras Gordas Tecate B.C. (id: ??, ns: 0),
#  Poundbury Hill (id: ??, ns: 0),
#  Tambo Viejo (id: ??, ns: 0),
#  Tell (id: ??, ns: 0),
#  Yacimiento arqueológico del Molino Manzánez (id: ??, ns: 0),
#  Yacimiento de las Amoladeras (id: ??, ns: 0),
#  Yacimientos neolíticos del Valle de Ambrona (id: ??, ns: 0),
#  Zafar (id: ??, ns: 0),
#  Ingeniería biomédica (id: ??, ns: 0),
#  BioMedical Engineering OnLine (id: ??, ns: 0),
#  Electromedicina (id: ??, ns: 0),
#  Encapsulamiento celular (id: ??, ns: 0),
#  Estimulación magnética transcraneana (id: ??, ns: 0),
#  Exoesqueleto mecánico (id: ??, ns: 0),
#  Ingeniería clínica (id: ??, ns: 0),
#  Páncreas artificial (id: ??, ns: 0),
#  Prótesis de retina Argus (id: ??, ns: 0),
#  Prótesis valvular cardíaca (id: ??, ns: 0),
#  The vOICe (id: ??, ns: 0),
#  Biónica (id: ??, ns: 0),
#  Arquitectura biónica (id: ??, ns: 0),
#  Biomimesis (id: ??, ns: 0),
#  Lente de contacto biónica (id: ??, ns: 0),
#  Computadora cognitiva (id: ??, ns: 0),
#  Cybathlon (id: ??, ns: 0),
#  Implante coclear (id: ??, ns: 0),
#  Robótica bioinspirada (id: ??, ns: 0),
#  Antena Cíborg (id: ??, ns: 0),
#  Artroplastia de rodilla (id: ??, ns: 0),
#  Artroplastia inversa de hombro (id: ??, ns: 0),
#  Biocerámicas (id: ??, ns: 0),
#  Catéter (id: ??, ns: 0),
#  Catéter venoso central (id: ??, ns: 0),
#  Cíborg (id: ??, ns: 0),
#  Corazón artificial (id: ??, ns: 0),
#  Dispositivo de asistencia ventricular (id: ??, ns: 0),
#  Esfínter urinario artificial (id: ??, ns: 0),
#  Estimulación del nervio vago (id: ??, ns: 0),
#  Implante (medicina) (id: ??, ns: 0),
#  Implante cerebral (id: ??, ns: 0),
#  Implante de pene (id: ??, ns: 0),
#  Implante dental (id: ??, ns: 0),
#  Implante dental análoga a la raíz (id: ??, ns: 0),
#  Implante subdérmico (id: ??, ns: 0),
#  Implantes de pene en lesiones de la médula espinal (id: ??, ns: 0),
#  Implantes de seno de polipropileno (id: ??, ns: 0),
#  Injerto (medicina) (id: ??, ns: 0),
#  Mamoplastia de aumento (id: ??, ns: 0),
#  Neuroprótesis (id: ??, ns: 0),
#  Órgano artificial (id: ??, ns: 0),
#  Periimplantitis (id: ??, ns: 0),
#  Prótesis de pene (id: ??, ns: 0),
#  Reemplazo de articulación (id: ??, ns: 0),
#  Reemplazo de rodilla (id: ??, ns: 0),
#  Stent bioabsorbible (id: ??, ns: 0),
#  Sustitución de la válvula aórtica (id: ??, ns: 0),
#  Prótesis (id: ??, ns: 0),
#  Audífono (id: ??, ns: 0),
#  Banco de Prótesis (id: ??, ns: 0),
#  Gluteoplastía (id: ??, ns: 0),
#  Jaula expansible para fusión intercorporal (id: ??, ns: 0),
#  Marcapasos cardíaco artificial (id: ??, ns: 0),
#  Marcapasos compatible con resonancia magnética (id: ??, ns: 0),
#  Osteointegración (id: ??, ns: 0),
#  Pata de palo (id: ??, ns: 0),
#  Polímero electroactivo (id: ??, ns: 0),
#  Prótesis impresas en 3D (id: ??, ns: 0),
#  Prótesis ocular (id: ??, ns: 0),
#  Prótesis ortopédica (id: ??, ns: 0),
#  Prótesis visual (id: ??, ns: 0),
#  Sistema de bolsa de ostomía (id: ??, ns: 0),
#  Válvula Bjork-Shiley (id: ??, ns: 0),
#  Annual Review of Biomedical Engineering (id: ??, ns: 0),
#  Biomedical Optics Express (id: ??, ns: 0),
#  Journal of Applied Biomechanics (id: ??, ns: 0),
#  Órgano en un chip (id: ??, ns: 0),
#  Organoide (id: ??, ns: 0),
#  Tissue Engineering and Regenerative Medicine International Society (id: ??, ns: 0),
#  Ingeniería genética (id: ??, ns: 0),
#  ADN hachimoji (id: ??, ns: 0),
#  ADN recombinante (id: ??, ns: 0),
#  Animal modificado genéticamente (id: ??, ns: 0),
#  Anti-CRISPR (id: ??, ns: 0),
#  Arabidopsis thaliana (id: ??, ns: 0),
#  Asunto Pusztai (id: ??, ns: 0),
#  ATryn (id: ??, ns: 0),
#  Biología DIY (id: ??, ns: 0),
#  Cas9 (id: ??, ns: 0),
#  Cas12a2 (id: ??, ns: 0),
#  Chacasina (id: ??, ns: 0),
#  Mary-Dell Chilton (id: ??, ns: 0),
#  Cisgénesis (id: ??, ns: 0),
#  Cpf1 (id: ??, ns: 0),
#  CRISPR (id: ??, ns: 0),
#  CRISPR/Cas (id: ??, ns: 0),
#  CRISPR/Cpf1 (id: ??, ns: 0),
#  Desextinción (id: ??, ns: 0),
#  Edición de genoma (id: ??, ns: 0),
#  Edición del epigenoma (id: ??, ns: 0),
#  Erradicación del sufrimiento (id: ??, ns: 0),
#  Etiquetado de transposones (id: ??, ns: 0),
#  Fago M13 (id: ??, ns: 0),
#  GENCODE (id: ??, ns: 0),
#  Genética dirigida (id: ??, ns: 0),
#  Cosechas modificadas genéticamente (id: ??, ns: 0),
#  Genpets (id: ??, ns: 0),
#  Herramientas de diseño de CRISPR-Cas (id: ??, ns: 0),
#  Historia de la ingeniería genética (id: ??, ns: 0),
#  Insecto genéticamente modificado (id: ??, ns: 0),
#  Introducción a la genética (id: ??, ns: 0),
#  Lipofección (id: ??, ns: 0),
#  Mendigos en España (id: ??, ns: 0),
#  Mendigos y opulentos (id: ??, ns: 0),
#  Metagenómica (id: ??, ns: 0),
#  Metaproteómica (id: ??, ns: 0),
#  Metatranscriptómica (id: ??, ns: 0),
#  Motivo adyacente de protoespaciador (id: ??, ns: 0),
#  Partenogénesis en mamíferos (id: ??, ns: 0),
#  Patente biológica (id: ??, ns: 0),
#  Péptidos de autoescisión 2A (id: ??, ns: 0),
#  Planta genéticamente modificada (id: ??, ns: 0),
#  Proteína recombinante (id: ??, ns: 0),
#  Ratón humanizado (id: ??, ns: 0),
#  Ratón knockout (id: ??, ns: 0),
#  Ratón modificado genéticamente (id: ??, ns: 0),
#  Ratón nude (id: ??, ns: 0),
#  Sistemas de Información Genética Artificialmente Expandidos (id: ??, ns: 0),
#  Somatotropina bovina (id: ??, ns: 0),
#  Sonda molecular (id: ??, ns: 0),
#  Técnicas de ingeniería genética (id: ??, ns: 0),
#  Test de Ames (id: ??, ns: 0),
#  Jacques Testart (id: ??, ns: 0),
#  ARN CRISPR transactivante (ARNtracr) (id: ??, ns: 0),
#  Transgén (id: ??, ns: 0),
#  Aaron Traywick (id: ??, ns: 0),
#  Clonación (id: ??, ns: 0),
#  Blastómero (id: ??, ns: 0),
#  Blástula (id: ??, ns: 0),
#  Keith Campbell (biólogo) (id: ??, ns: 0),
#  Célula germinal (humana) (id: ??, ns: 0),
#  Célula madre (id: ??, ns: 0),
#  Célula madre pluripotente inducida (id: ??, ns: 0),
#  Célula progenitora (id: ??, ns: 0),
#  Célula somática (id: ??, ns: 0),
#  Clon (id: ??, ns: 0),
#  Clonación de especies extintas (id: ??, ns: 0),
#  Clonación extensa (id: ??, ns: 0),
#  Clonación humana (id: ??, ns: 0),
#  Clonación posicional (id: ??, ns: 0),
#  Cóntigo (id: ??, ns: 0),
#  Cordón umbilical (id: ??, ns: 0),
#  Cósmido (id: ??, ns: 0),
#  Cromosoma artificial bacteriano (id: ??, ns: 0),
#  Cromosoma artificial de levadura (id: ??, ns: 0),
#  Electroporación (id: ??, ns: 0),
#  Ética de la clonación (id: ??, ns: 0),
#  Fagémido (id: ??, ns: 0),
#  Gen (id: ??, ns: 0),
#  Instituto Roslin (id: ??, ns: 0),
#  Mórula (id: ??, ns: 0),
#  Mycocepurus smithii (id: ??, ns: 0),
#  Óvulo (id: ??, ns: 0),
#  Transferencia nuclear celular (id: ??, ns: 0),
#  Transferencia nuclear de células somáticas (id: ??, ns: 0),
#  Vector de clonación (id: ??, ns: 0),
#  Jean Weissenbach (id: ??, ns: 0),
#  Ian Wilmut (id: ??, ns: 0),
#  Actividad star (id: ??, ns: 0),
#  BamHI (id: ??, ns: 0),
#  BglII (id: ??, ns: 0),
#  EcoRI (id: ??, ns: 0),
#  EcoRII (id: ??, ns: 0),
#  EcoRV (id: ??, ns: 0),
#  Endonucleasa homing (id: ??, ns: 0),
#  Enzima de restricción (id: ??, ns: 0),
#  FokI (id: ??, ns: 0),
#  HaeIII (id: ??, ns: 0),
#  HindII (id: ??, ns: 0),
#  HindIII (id: ??, ns: 0),
#  HpaII (id: ??, ns: 0),
#  Isoesquizómero (id: ??, ns: 0),
#  Nucleasas con dedos de zinc (id: ??, ns: 0),
#  PstI (id: ??, ns: 0),
#  SmaI (id: ??, ns: 0),
#  Traslación de la muesca (id: ??, ns: 0),
#  Organismo genéticamente modificado (id: ??, ns: 0),
#  Alimento transgénico (id: ??, ns: 0),
#  ANDi (id: ??, ns: 0),
#  Bacteria modificada genéticamente (id: ??, ns: 0),
#  Biolística (id: ??, ns: 0),
#  Dinastía Pampa (id: ??, ns: 0),
#  Injaz (id: ??, ns: 0),
#  Knockdown de genes (id: ??, ns: 0),
#  Ley de Bioseguridad de Organismos Genéticamente Modificados de México (id: ??, ns: 0),
#  Mamíferos modificados genéticamente (id: ??, ns: 0),
#  Mutagénesis (técnica de biología molecular) (id: ??, ns: 0),
#  Nidera (id: ??, ns: 0),
#  Oncoratón (id: ??, ns: 0),
#  Oveja Dolly (id: ??, ns: 0),
#  Oveja Polly (id: ??, ns: 0),
#  Pampa (vaca) (id: ??, ns: 0),
#  Pampa Mansa (id: ??, ns: 0),
#  Peces transgénicos fluorescentes de acuario (id: ??, ns: 0),
#  Peces modificados genéticamente (id: ??, ns: 0),
#  Super p53 (id: ??, ns: 0),
#  Syngenta (id: ??, ns: 0),
#  Teorías conspirativas sobre los OMG (id: ??, ns: 0),
#  Virus modificado genéticamente (id: ??, ns: 0),
#  Zhong Zhong y Hua Hua (id: ??, ns: 0),
#  Eteplirsén (id: ??, ns: 0),
#  Etranacogene dezaparvovec (id: ??, ns: 0),
#  Oligonucleótido antisentido (id: ??, ns: 0),
#  Onasemnogene abeparvovec (id: ??, ns: 0),
#  Receptor de antígeno quimérico (id: ??, ns: 0),
#  Strímvelis (id: ??, ns: 0),
#  Terapia de reemplazo mitocondrial (id: ??, ns: 0),
#  Terapia génica (id: ??, ns: 0),
#  Terapia génica antirretroviral (id: ??, ns: 0),
#  Tisagenlecleucel (id: ??, ns: 0),
#  Voretigene neparvovec (id: ??, ns: 0),
#  Biomaterial (id: ??, ns: 0),
#  Material autorreparante (id: ??, ns: 0),
#  Péptidos anfifílicos (id: ??, ns: 0),
#  Polietilenglicol (id: ??, ns: 0),
#  Starlite (id: ??, ns: 0),
#  Vitalio (id: ??, ns: 0),
#  Titanio (id: ??, ns: 0),
#  Biología (id: ??, ns: 0),
#  A genome- scale screen for synthetic drivers of T cell proliferation (id: ??, ns: 0),
#  Antropología biocultural (id: ??, ns: 0),
#  Biología cuantitativa (id: ??, ns: 0),
#  Bioproducción (id: ??, ns: 0),
#  Biosemiótica (id: ??, ns: 0),
#  Biosfera profunda (id: ??, ns: 0),
#  Buccinastrum deforme (id: ??, ns: 0),
#  Centroneuralia (id: ??, ns: 0),
#  Ciencias del karst (id: ??, ns: 0),
#  Clipnosis (id: ??, ns: 0),
#  Curvatura lumbar de 45 grados (id: ??, ns: 0),
#  Datos biológicos (id: ??, ns: 0),
#  Desarrollo postembrionario (id: ??, ns: 0),
#  EF-G (id: ??, ns: 0),
#  Endogenia (biología) (id: ??, ns: 0),
#  Endosexualidad (id: ??, ns: 0),
#  Evolución de la moralidad (id: ??, ns: 0),
#  Fenestral (id: ??, ns: 0),
#  Gen GALNS (id: ??, ns: 0),
#  Cristina Mittermeier (id: ??, ns: 0),
#  Hemotafonomía (id: ??, ns: 0),
#  Imagen de fluorescencias (id: ??, ns: 0),
#  Instituto para la Investigación Biológica de Israel (id: ??, ns: 0),
#  Material de Construcción Viviente (id: ??, ns: 0),
#  Microbiología (id: ??, ns: 0),
#  Leonora Milán (id: ??, ns: 0),
#  Multiómica (id: ??, ns: 0),
#  Nassariidae (id: ??, ns: 0),
#  Neontología (id: ??, ns: 0),
#  Noxa (id: ??, ns: 0),
#  Olimpiada Iberoamericana de Biología (id: ??, ns: 0),
#  Olimpiada Peruana de Biología (id: ??, ns: 0),
#  Péptido C (id: ??, ns: 0),
#  Permutación circular en proteínas (id: ??, ns: 0),
#  Principales características de los seres vivos (id: ??, ns: 0),
#  Principio de los subsistemas de conjugados por V. Geodakian (id: ??, ns: 0),
#  Proyecto Web del Árbol de la vida (id: ??, ns: 0),
#  Putrefacción (id: ??, ns: 0),
#  Q10 (coeficiente de temperatura) (id: ??, ns: 0),
#  Química forense (id: ??, ns: 0),
#  Sexado (id: ??, ns: 0),
#  Sintrofía (id: ??, ns: 0),
#  Sistema biológico (id: ??, ns: 0),
#  Teleología en biología (id: ??, ns: 0),
#  Termodinámica biológica (id: ??, ns: 0),
#  Thanatosdrakon amaru (id: ??, ns: 0),
#  Transición epitelio-mesénquima (id: ??, ns: 0),
#  Vitaminas liposolubles (id: ??, ns: 0),
#  Biólogo (id: ??, ns: 0),
#  Rie de Boois (id: ??, ns: 0),
#  Ivan Erill (id: ??, ns: 0),
#  Michael Eisen (id: ??, ns: 0),
#  René Ngongo (id: ??, ns: 0),
#  Durk Pearson (id: ??, ns: 0),
#  Robert E. Hueter (id: ??, ns: 0),
#  Diara Rocha (id: ??, ns: 0),
#  Steven M. Stanley (id: ??, ns: 0),
#  Ana María Viñas Díaz (id: ??, ns: 0),
#  Jill Yager (id: ??, ns: 0),
#  Geneviève Almouzni (id: ??, ns: 0),
#  Karla Aparicio (id: ??, ns: 0),
#  Emily Arnesen (id: ??, ns: 0),
#  Arita Baaijens (id: ??, ns: 0),
#  Yasmine Belkaid (id: ??, ns: 0),
#  Idelisa Bonnelly (id: ??, ns: 0),
#  Ana Colovic Lesoska (id: ??, ns: 0),
#  Valerie Todd Davies (id: ??, ns: 0),
#  Anne Dejean-Assémat (id: ??, ns: 0),
#  Sandra Myrna Díaz (id: ??, ns: 0),
#  Effa Funk Muhse (id: ??, ns: 0),
#  Alice Embleton (id: ??, ns: 0),
#  Eunice Enríquez (id: ??, ns: 0),
#  Elena de Galantha (id: ??, ns: 0),
#  Janet Gibson (id: ??, ns: 0),
#  Olga Guramishvili-Nikoladze (id: ??, ns: 0),
#  María Luisa Izaguirre (id: ??, ns: 0),
#  Aban Marker Kabraji (id: ??, ns: 0),
#  Paula Kahumbu (id: ??, ns: 0),
#  Janet Kelso (id: ??, ns: 0),
#  Eva Klein (id: ??, ns: 0),
#  Yvonne Kranz-Baltensperger (id: ??, ns: 0),
#  Titia de Lange (id: ??, ns: 0),
#  Los Ángeles de Leakey (id: ??, ns: 0),
#  Beronda Montgomery (id: ??, ns: 0),
#  Indira Nath (id: ??, ns: 0),
#  Liseth Pérez Alvarado (id: ??, ns: 0),
#  Biljana Plavšić (id: ??, ns: 0),
#  María Concepción Rodríguez de la Cruz (id: ??, ns: 0),
#  Zehra Sayers (id: ??, ns: 0),
#  Lubna Tahtamouni (id: ??, ns: 0),
#  Anna Thynne (id: ??, ns: 0),
#  Brigitta I. van Tussenbroek (id: ??, ns: 0),
#  Ximena Vélez Liendo (id: ??, ns: 0),
#  Loles Vives (id: ??, ns: 0),
#  Narcisa Martínez (id: ??, ns: 0),
#  Petre Mihai Bănărescu (id: ??, ns: 0),
#  Aldrich Killian (id: ??, ns: 0),
#  Alec Holland (id: ??, ns: 0),
#  Amo de las Marionetas (id: ??, ns: 0),
#  Atomic Skull (id: ??, ns: 0),
#  Caballero Negro (Nathan Garrett) (id: ??, ns: 0),
#  Rubeus Hagrid (id: ??, ns: 0),
#  Jotaro Kujo (id: ??, ns: 0),
#  Lemuel Dorcas (personaje) (id: ??, ns: 0),
#  Maelstrom (Marvel Comics) (id: ??, ns: 0),
#  Man-Bat (id: ??, ns: 0),
#  Mercy (Overwatch) (id: ??, ns: 0),
#  Mister Hyde (cómic) (id: ??, ns: 0),
#  Míster Siniestro (id: ??, ns: 0),
#  Morbius (id: ??, ns: 0),
#  Pájaro Burlón (id: ??, ns: 0),
#  Paul Stamets (Star Trek) (id: ??, ns: 0),
#  Rosa y Espina (id: ??, ns: 0),
#  Señor Siniestro (id: ??, ns: 0),
#  Stephen Shin (id: ??, ns: 0),
#  Silvestre Tornasol (id: ??, ns: 0),
#  Chit Ko Ko (id: ??, ns: 0),
#  Sandi Hilal (id: ??, ns: 0),
#  Tha Hla (id: ??, ns: 0),
#  Vida (id: ??, ns: 0),
#  Esperanza de vida (id: ??, ns: 0),
#  Género de vida (id: ??, ns: 0),
#  Historia de la vida cotidiana (id: ??, ns: 0),
#  Inmortalidad (id: ??, ns: 0),
#  Nacimiento (id: ??, ns: 0),
#  Prolongación de la vida (id: ??, ns: 0),
#  Quiralidad (id: ??, ns: 0),
#  Sedula mater (id: ??, ns: 0),
#  Sentido de la vida (id: ??, ns: 0),
#  Ser vivo (id: ??, ns: 0),
#  Sistema vivo (id: ??, ns: 0),
#  Teoría del curso de vida (id: ??, ns: 0),
#  Vida (desambiguación) (id: ??, ns: 0),
#  Vida basada en carbono (id: ??, ns: 0),
#  Vida útil (id: ??, ns: 0),
#  Amor fati (id: ??, ns: 0),
#  Autorreflexión humana (id: ??, ns: 0),
#  Axiarquía (id: ??, ns: 0),
#  Crisis existencial (id: ??, ns: 0),
#  Estilo de vida (id: ??, ns: 0),
#  Filosofía de la felicidad (id: ??, ns: 0),
#  Filosofía del absurdo (id: ??, ns: 0),
#  Libre albedrío (id: ??, ns: 0),
#  Magnum in parvo: Una filosofía en compendio (id: ??, ns: 0),
#  Orden de la Buena Muerte (id: ??, ns: 0),
#  Pesimismo filosófico (id: ??, ns: 0),
#  Racionalismo moral (id: ??, ns: 0),
#  Religión de la humanidad (id: ??, ns: 0),
#  Filosofía del suicidio (id: ??, ns: 0),
#  Tanatofobia (id: ??, ns: 0),
#  Tao (id: ??, ns: 0),
#  Tri Hita Karana (id: ??, ns: 0),
#  Visualización negativa (id: ??, ns: 0),
#  Cinetótrofo (id: ??, ns: 0),
#  Formas propuestas de vida (id: ??, ns: 0),
#  Nanobacteria (id: ??, ns: 0),
#  Nanobio (id: ??, ns: 0),
#  Vida extraterrestre (id: ??, ns: 0),
#  Amrita (id: ??, ns: 0),
#  Árbol de la vida (id: ??, ns: 0),
#  Árbol de la vida (bíblico) (id: ??, ns: 0),
#  El fin del envejecimiento (id: ??, ns: 0),
#  Eterna juventud (id: ??, ns: 0),
#  Eternidad (id: ??, ns: 0),
#  Fénix (id: ??, ns: 0),
#  Fuente de la juventud (id: ??, ns: 0),
#  Aubrey de Grey (id: ??, ns: 0),
#  Inmortalidad biológica (id: ??, ns: 0),
#  Raymond Kurzweil (id: ??, ns: 0),
#  Transferencia mental (id: ??, ns: 0),
#  Transhumanismo (id: ??, ns: 0),
#  Turritopsis dohrnii (id: ??, ns: 0),
#  Turritopsis nutricula (id: ??, ns: 0),
#  Vida después de la muerte (id: ??, ns: 0),
#  Muerte (id: ??, ns: 0),
#  Análisis de la supervivencia (id: ??, ns: 0),
#  Comunicación después de la muerte inducida (id: ??, ns: 0),
#  Conciencia después de la muerte (id: ??, ns: 0),
#  Muerte de Dios (id: ??, ns: 0),
#  Doula del final de la vida (id: ??, ns: 0),
#  Efecto cumpleaños (id: ??, ns: 0),
#  Escala de Miedo a la Muerte de Collett Lester (id: ??, ns: 0),
#  Eutanasia (id: ??, ns: 0),
#  Exceso de mortalidad (id: ??, ns: 0),
#  Fauna cadavérica (id: ??, ns: 0),
#  Filosofía del Cuidado de la Salud (id: ??, ns: 0),
#  Kodokushi (id: ??, ns: 0),
#  Limpieza sueca para la muerte (id: ??, ns: 0),
#  Muerte asistida (id: ??, ns: 0),
#  Muerte digna (id: ??, ns: 0),
#  Muerte teórica de información (id: ??, ns: 0),
#  Muerte triple (id: ??, ns: 0),
#  Necrocapitalismo (id: ??, ns: 0),
#  Necrónimo (id: ??, ns: 0),
#  Necropolítica (id: ??, ns: 0),
#  Robo de cuerpos (id: ??, ns: 0),
#  Secreciones respiratorias terminales (id: ??, ns: 0),
#  Senicidio (id: ??, ns: 0),
#  Sociología de la muerte (id: ??, ns: 0),
#  Tablas de mortalidad (id: ??, ns: 0),
#  Tanatosis (id: ??, ns: 0),
#  Teoría del manejo del terror (id: ??, ns: 0),
#  Theta nigrum (id: ??, ns: 0),
#  Abiogénesis (id: ??, ns: 0),
#  Acelular (id: ??, ns: 0),
#  Ácido peptidonucleico (id: ??, ns: 0),
#  Akilia (id: ??, ns: 0),
#  Analogía del relojero (id: ??, ns: 0),
#  Autoensamblaje (id: ??, ns: 0),
#  Biogénesis (id: ??, ns: 0),
#  Bugonia (id: ??, ns: 0),
#  Caldo primigenio (id: ??, ns: 0),
#  Cinturón de rocas verdes de Isua (id: ??, ns: 0),
#  Ciudad Perdida (campo hidrotermal) (id: ??, ns: 0),
#  Coacervado (id: ??, ns: 0),
#  Colina primigenia (id: ??, ns: 0),
#  Coloide (id: ??, ns: 0),
#  Conjunto autocatalítico (id: ??, ns: 0),
#  Creacionismo (id: ??, ns: 0),
#  Creacionismo de la Tierra joven (id: ??, ns: 0),
#  Creacionismo de Tierra vieja (id: ??, ns: 0),
#  Christian de Duve (id: ??, ns: 0),
#  John Edmonstone (id: ??, ns: 0),
#  Manfred Eigen (id: ??, ns: 0),
#  Experimento de Miller y Urey (id: ??, ns: 0),
#  Falacia de Hoyle (id: ??, ns: 0),
#  Sidney W. Fox (id: ??, ns: 0),
#  Generación espontánea (id: ??, ns: 0),
#  John Burdon Sanderson Haldane (id: ??, ns: 0),
#  Hipótesis de la Tierra especial (id: ??, ns: 0),
#  Hipótesis del citoplasma fuera (id: ??, ns: 0),
#  Hipótesis del mundo de ARN (id: ??, ns: 0),
#  Hipótesis del mundo de HAP (id: ??, ns: 0),
#  Stuart Alan Kauffman (id: ??, ns: 0),
#  Jean-Baptiste Lamarck (id: ??, ns: 0),
#  Anton van Leeuwenhoek (id: ??, ns: 0),
#  Meteorito Murchison (id: ??, ns: 0),
#  Monstruo de Spiegelman (id: ??, ns: 0),
#  Aleksandr Oparin (id: ??, ns: 0),
#  Leslie Orgel (id: ??, ns: 0),
#  Juan Oró (id: ??, ns: 0),
#  Panspermia (id: ??, ns: 0),
#  Louis Pasteur (id: ??, ns: 0),
#  Principio antrópico (id: ??, ns: 0),
#  Protobionte (id: ??, ns: 0),
#  Reacción de la formosa (id: ??, ns: 0),
#  Francesco Redi (id: ??, ns: 0),
#  Ribozima (id: ??, ns: 0),
#  Selección natural (id: ??, ns: 0),
#  Lazzaro Spallanzani (id: ??, ns: 0),
#  Teoría de la síntesis abiótica (id: ??, ns: 0),
#  Teoría del mundo de hierro-azufre (id: ??, ns: 0),
#  Teoría quimiosintética (id: ??, ns: 0),
#  Tioéster (id: ??, ns: 0),
#  Tolina (id: ??, ns: 0),
#  Transpermia (id: ??, ns: 0),
#  Último antepasado común universal (id: ??, ns: 0),
#  Viroide (id: ??, ns: 0),
#  Günter Wächtershäuser (id: ??, ns: 0),
#  Baopuzi (id: ??, ns: 0),
#  José Luis Cordeiro (id: ??, ns: 0),
#  Criónica (id: ??, ns: 0),
#  Nicotinamida mononucleótida (id: ??, ns: 0),
#  Premio Breakthrough en Ciencias de la Vida (id: ??, ns: 0),
#  Reloj epigenético (id: ??, ns: 0),
#  Terapia con células madre (id: ??, ns: 0),
#  Adelfogamia (id: ??, ns: 0),
#  Aislamiento geográfico (id: ??, ns: 0),
#  Alternancia de generaciones (id: ??, ns: 0),
#  Reproducción alternante (id: ??, ns: 0),
#  Altricial (id: ??, ns: 0),
#  Androconio (id: ??, ns: 0),
#  Anteridio (id: ??, ns: 0),
#  Anterozoide (id: ??, ns: 0),
#  Apareamiento (id: ??, ns: 0),
#  Autofecundación (id: ??, ns: 0),
#  Bebé de diseño (id: ??, ns: 0),
#  Biología reproductiva (id: ??, ns: 0),
#  Cariogamia (id: ??, ns: 0),
#  Castración química (id: ??, ns: 0),
#  Ciclo biológico de vida (id: ??, ns: 0),
#  Ciclo de vida haplodiplonte (id: ??, ns: 0),
#  Ciclo replicativo de los virus (id: ??, ns: 0),
#  Cópula (zoología) (id: ??, ns: 0),
#  Corpúsculo polar (id: ??, ns: 0),
#  Cuerpo fructífero (plasmodio) (id: ??, ns: 0),
#  Desarrollo prenatal (id: ??, ns: 0),
#  Descendencia (id: ??, ns: 0),
#  Dimorfismo generacional (id: ??, ns: 0),
#  Dimorfismo sexual (id: ??, ns: 0),
#  Dioico (id: ??, ns: 0),
#  Disgenesia (id: ??, ns: 0),
#  Donación de esperma (id: ??, ns: 0),
#  Donación de ovocitos (id: ??, ns: 0),
#  Efecto Wallace (id: ??, ns: 0),
#  Embrión (id: ??, ns: 0),
#  Espermateca (id: ??, ns: 0),
#  Espermatóforo (id: ??, ns: 0),
#  Espermatozoide (id: ??, ns: 0),
#  Espermiogénesis (id: ??, ns: 0),
#  Esterilidad (id: ??, ns: 0),
#  Esterilización forzada en los Estados Unidos (id: ??, ns: 0),
#  Esterilización forzosa (id: ??, ns: 0),
#  Esterilización ultravioleta (id: ??, ns: 0),
#  Eugenesia liberal (id: ??, ns: 0),
#  Fecundidad (id: ??, ns: 0),
#  Femenino (id: ??, ns: 0),
#  Fertilidad (id: ??, ns: 0),
#  Feto (id: ??, ns: 0),
#  Gametangio (id: ??, ns: 0),
#  Gameto (id: ??, ns: 0),
#  Gametocito (id: ??, ns: 0),
#  Gametogénesis (id: ??, ns: 0),
#  Gametogonia (id: ??, ns: 0),
#  Gemelos semi idénticos (id: ??, ns: 0),
#  Generaciones telescópicas (id: ??, ns: 0),
#  Gestación (id: ??, ns: 0),
#  Gonocorismo (id: ??, ns: 0),
#  Hembra (id: ??, ns: 0),
#  Hermafroditismo (id: ??, ns: 0),
#  Heterocronía (id: ??, ns: 0),
#  Heterogamia (id: ??, ns: 0),
#  Hija (id: ??, ns: 0),
#  Hipótesis del costo de la reproducción (id: ??, ns: 0),
#  Ictioplancton (id: ??, ns: 0),
#  Incubación (id: ??, ns: 0),
#  Incubación bucal (id: ??, ns: 0),
#  Inmunología de la reproducción (id: ??, ns: 0),
#  Inseminación artificial (id: ??, ns: 0),
#  Instituto Chileno de Medicina Reproductiva (id: ??, ns: 0),
#  Interfertilidad (id: ??, ns: 0),
#  La familia Kallikak (id: ??, ns: 0),
#  Lecha (id: ??, ns: 0),
#  Macho (id: ??, ns: 0),
#  Masculino (id: ??, ns: 0),
#  Microbiota uterina (id: ??, ns: 0),
#  Microquimerismo (id: ??, ns: 0),
#  Monocarpismo (id: ??, ns: 0),
#  Nacimiento múltiple (id: ??, ns: 0),
#  Oospora (id: ??, ns: 0),
#  Ooteca (id: ??, ns: 0),
#  Operación Manos a la Obra (id: ??, ns: 0),
#  Ovogonia (id: ??, ns: 0),
#  Ovoviviparidad (id: ??, ns: 0),
#  Partenote (id: ??, ns: 0),
#  Polispermia (id: ??, ns: 0),
#  Principio de Fisher (id: ??, ns: 0),
#  Productos de la concepción (id: ??, ns: 0),
#  Pronúcleo (id: ??, ns: 0),
#  Proporciones sexuales (id: ??, ns: 0),
#  Quimiotaxis en espermatozoides marinos (id: ??, ns: 0),
#  Reacción acrosómica (id: ??, ns: 0),
#  Reproducción (id: ??, ns: 0),
#  Reproducción asistida (id: ??, ns: 0),
#  Reproducción asistida en el cristianismo (id: ??, ns: 0),
#  Reproducción asistida en el Islam (id: ??, ns: 0),
#  Reproducción asistida en el judaísmo (id: ??, ns: 0),
#  Reproducción sexual (id: ??, ns: 0),
#  Salud reproductiva (id: ??, ns: 0),
#  Semelparidad e iteroparidad (id: ??, ns: 0),
#  Sexo (id: ??, ns: 0),
#  Sin hijos por elección (id: ??, ns: 0),
#  Spermbot (id: ??, ns: 0),
#  Superfecundación (id: ??, ns: 0),
#  Superfetación (id: ??, ns: 0),
#  Teleomorfo (id: ??, ns: 0),
#  Telitoquia (id: ??, ns: 0),
#  Teoría de la evolución de las relaciones sexuales por V. Geodakian (id: ??, ns: 0),
#  Nuggle (id: ??, ns: 0),
#  Xenu (id: ??, ns: 0),
#  Algoritmo genético (id: ??, ns: 0),
#  Autorreplicación (id: ??, ns: 0),
#  Code of the Lifemaker (id: ??, ns: 0),
#  Comportamiento de bandada (id: ??, ns: 0),
#  Computación evolutiva (id: ??, ns: 0),
#  Core War (id: ??, ns: 0),
#  Estrategia evolutiva (id: ??, ns: 0),
#  Hashlife (id: ??, ns: 0),
#  Hormiga de Langton (id: ??, ns: 0),
#  Juego de la vida (id: ??, ns: 0),
#  Máquina autorreplicante (id: ??, ns: 0),
#  Materia activa (id: ??, ns: 0),
#  Matusalén (autómata celular) (id: ??, ns: 0),
#  Mundo de margaritas (id: ??, ns: 0),
#  Nave espacial autorreplicante (id: ??, ns: 0),
#  Organismo digital (id: ??, ns: 0),
#  Oscilador (autómata celular) (id: ??, ns: 0),
#  Plaga gris (id: ??, ns: 0),
#  Programa Weasel (id: ??, ns: 0),
#  Programación evolutiva (id: ??, ns: 0),
#  Semillas (autómata celular) (id: ??, ns: 0),
#  Velocidad de la luz (autómata celular) (id: ??, ns: 0),
#  Vida artificial (id: ??, ns: 0),
#  Agua extraterrestre (id: ??, ns: 0),
#  Alienígenas sigilosos y ruidosos (id: ??, ns: 0),
#  Chovinismo del carbono (id: ??, ns: 0),
#  Conjetura de Hart-Tipler (id: ??, ns: 0),
#  Exoarqueología (id: ??, ns: 0),
#  Exoteología (id: ??, ns: 0),
#  Experimentos biológicos de las naves Viking (id: ??, ns: 0),
#  Gran filtro (id: ??, ns: 0),
#  Hipótesis del berserker (id: ??, ns: 0),
#  Hipótesis del bosque oscuro (id: ??, ns: 0),
#  Hipótesis del primogénito (id: ??, ns: 0),
#  Lenguaje extraterrestre (id: ??, ns: 0),
#  Momias de Nazca (id: ??, ns: 0),
#  Tecnomarcador (id: ??, ns: 0),
#  Afectividad (id: ??, ns: 0),
#  Afecto (id: ??, ns: 0),
#  Comportamiento sexual humano (id: ??, ns: 0),
#  Conciliación de la vida familiar y laboral (id: ??, ns: 0),
#  Condición humana (id: ??, ns: 0),
#  Confianza (id: ??, ns: 0),
#  Habilidades para la vida (id: ??, ns: 0),
#  Naturaleza humana (id: ??, ns: 0),
#  Ne quid nimis (id: ??, ns: 0),
#  Nómada digital (id: ??, ns: 0),
#  Postura ante la vida (id: ??, ns: 0),
#  Recopilación de información de identificación personal (id: ??, ns: 0),
#  Rico en dinero, pobre en tiempo (id: ??, ns: 0),
#  Sexualidad humana (id: ??, ns: 0),
#  Aerobiología (id: ??, ns: 0),
#  Alometría (id: ??, ns: 0),
#  Anatomía (id: ??, ns: 0),
#  Astrobiología (id: ??, ns: 0),
#  Bioacústica (id: ??, ns: 0),
#  Bioclimatología (id: ??, ns: 0),
#  Bioespeleología (id: ??, ns: 0),
#  Biogeología (id: ??, ns: 0),
#  Biología experimental (id: ??, ns: 0),
#  Biología forense (id: ??, ns: 0),
#  Biología humana (id: ??, ns: 0),
#  Biología química (id: ??, ns: 0),
#  Biomedicina (id: ??, ns: 0),
#  Biomusicología (id: ??, ns: 0),
#  Criobiología (id: ??, ns: 0),
#  Biología cuántica (id: ??, ns: 0),
#  Escotobiología (id: ??, ns: 0),
#  Etnobiología (id: ??, ns: 0),
#  Fisiología (id: ??, ns: 0),
#  Fotobiología (id: ??, ns: 0),
#  Gerontología (id: ??, ns: 0),
#  Glicobiología (id: ??, ns: 0),
#  Hidrobiología (id: ??, ns: 0),
#  Liquenología (id: ??, ns: 0),
#  Mecanobiología (id: ??, ns: 0),
#  Monitor clínico (id: ??, ns: 0),
#  Morfología (biología) (id: ??, ns: 0),
#  Patología (id: ??, ns: 0),
#  Protistología (id: ??, ns: 0),
#  Sindrome de Morton's (id: ??, ns: 0),
#  Síndrome de Strasburger-Hawkins-Eldridge (id: ??, ns: 0),
#  Zoología (id: ??, ns: 0),
#  Acarología (id: ??, ns: 0),
#  Artropodología (id: ??, ns: 0),
#  Carcinología (id: ??, ns: 0),
#  Etnozoología (id: ??, ns: 0),
#  Helmintología (id: ??, ns: 0),
#  Paleozoología (id: ??, ns: 0),
#  Teratología (id: ??, ns: 0),
#  Zooarqueología (id: ??, ns: 0),
#  Agrostología (id: ??, ns: 0),
#  Antecología (id: ??, ns: 0),
#  Astrobotánica (id: ??, ns: 0),
#  Botánica especial (id: ??, ns: 0),
#  Botánica forestal (id: ??, ns: 0),
#  Botánica marina (id: ??, ns: 0),
#  Briología (id: ??, ns: 0),
#  Criptobotánica (id: ??, ns: 0),
#  Ficología (id: ??, ns: 0),
#  Fitosociología (id: ??, ns: 0),
#  Malherbología (id: ??, ns: 0),
#  Paleoetnobotánica (id: ??, ns: 0),
#  Pomología (id: ??, ns: 0),
#  Amígdala cerebelosa (id: ??, ns: 0),
#  Amplitud de movimiento articular (id: ??, ns: 0),
#  Anastomosis (id: ??, ns: 0),
#  Anatomía animal (id: ??, ns: 0),
#  Anatomía artística (id: ??, ns: 0),
#  Anatomía de los peces (id: ??, ns: 0),
#  Anatomía de superficie (id: ??, ns: 0),
#  Anatomía macroscópica (id: ??, ns: 0),
#  Anatomía sistemática (id: ??, ns: 0),
#  Anatomía topográfica (id: ??, ns: 0),
#  Anatomía vegetal (id: ??, ns: 0),
#  Anfiteatro anatómico (id: ??, ns: 0),
#  Anfiteatro anatómico de Padua (id: ??, ns: 0),
#  Ángulo de Djian-Annonier (id: ??, ns: 0),
#  Aorta (id: ??, ns: 0),
#  Aparato digestivo (id: ??, ns: 0),
#  Aponeurosis (id: ??, ns: 0),
#  Aracnoides (id: ??, ns: 0),
#  Arte y anatomía (id: ??, ns: 0),
#  Arteria (id: ??, ns: 0),
#  Arteria axilar (id: ??, ns: 0),
#  Arteria braquial (id: ??, ns: 0),
#  Arteria circunfleja femoral lateral (id: ??, ns: 0),
#  Arteria circunfleja femoral medial (id: ??, ns: 0),
#  Arteria circunfleja ilíaca superficial (id: ??, ns: 0),
#  Arteria colateral cubital inferior (id: ??, ns: 0),
#  Arteria colateral cubital superior (id: ??, ns: 0),
#  Arteria colateral media (id: ??, ns: 0),
#  Arteria colateral radial (id: ??, ns: 0),
#  Arteria descendente de la rodilla (id: ??, ns: 0),
#  Arteria epigástrica superficial (id: ??, ns: 0),
#  Arteria femoral (id: ??, ns: 0),
#  Arteria femoral profunda (id: ??, ns: 0),
#  Arteria inferior lateral de la rodilla (id: ??, ns: 0),
#  Arteria inferior medial de la rodilla (id: ??, ns: 0),
#  Arteria interósea recurrente (id: ??, ns: 0),
#  Arteria maleolar anterior lateral (id: ??, ns: 0),
#  Arteria maleolar anterior medial (id: ??, ns: 0),
#  Arteria media de la rodilla (id: ??, ns: 0),
#  Arteria poplítea (id: ??, ns: 0),
#  Arteria profunda del brazo (id: ??, ns: 0),
#  Arteria pudenda externa profunda (id: ??, ns: 0),
#  Arteria pudenda externa superficial (id: ??, ns: 0),
#  Arteria pulmonar derecha (id: ??, ns: 0),
#  Arteria radial (id: ??, ns: 0),
#  Arteria recurrente cubital (id: ??, ns: 0),
#  Arteria recurrente radial (id: ??, ns: 0),
#  Arteria recurrente tibial anterior (id: ??, ns: 0),
#  Arteria subclavia (id: ??, ns: 0),
#  Arteria superior lateral de la rodilla (id: ??, ns: 0),
#  Arteria superior medial de la rodilla (id: ??, ns: 0),
#  Arteria tibial anterior (id: ??, ns: 0),
#  Arteria umbilical (id: ??, ns: 0),
#  Arterias surales (id: ??, ns: 0),
#  Articulación (anatomía) (id: ??, ns: 0),
#  Articulación del hombro (id: ??, ns: 0),
#  Artrología (id: ??, ns: 0),
#  Aurícula (corazón) (id: ??, ns: 0),
#  Aurícula derecha (id: ??, ns: 0),
#  Aurícula izquierda (id: ??, ns: 0),
#  Biología de la depresión (id: ??, ns: 0),
#  Body Worlds (id: ??, ns: 0),
#  Braquidactilia tipo D (id: ??, ns: 0),
#  Buche (id: ??, ns: 0),
#  Caja torácica humana (id: ??, ns: 0),
#  Capilar sanguíneo (id: ??, ns: 0),
#  Cápsula renal (id: ??, ns: 0),
#  Circunvoluciones occipitales (id: ??, ns: 0),
#  Giro angular (id: ??, ns: 0),
#  Giro dentado (id: ??, ns: 0),
#  Giro frontal inferior (id: ??, ns: 0),
#  Giro frontal medial (id: ??, ns: 0),
#  Giro frontal medio (id: ??, ns: 0),
#  Giro frontal superior (id: ??, ns: 0),
#  Giro fusiforme (id: ??, ns: 0),
#  Giro largo de la ínsula (id: ??, ns: 0),
#  Giro lingual (id: ??, ns: 0),
#  Giro parahipocampal (id: ??, ns: 0),
#  Giro paraterminal (id: ??, ns: 0),
#  Giro poscentral (id: ??, ns: 0),
#  Giro precentral (id: ??, ns: 0),
#  Giro recto (id: ??, ns: 0),
#  Giro supramarginal (id: ??, ns: 0),
#  Giro temporal inferior (id: ??, ns: 0),
#  Giro temporal medio (id: ??, ns: 0),
#  Giro temporal superior (id: ??, ns: 0),
#  Giros cortos de la ínsula (id: ??, ns: 0),
#  Giros de la ínsula (id: ??, ns: 0),
#  Giros orbitarios (id: ??, ns: 0),
#  Giros temporales transversos (id: ??, ns: 0),
#  Lóbulo paracentral (id: ??, ns: 0),
#  Uncus (id: ??, ns: 0),
#  Cerebro triúnico (id: ??, ns: 0),
#  Ciclo nasal (id: ??, ns: 0),
#  Circulación portal hepática (id: ??, ns: 0),
#  Cisura (anatomía) (id: ??, ns: 0),
#  Cisura (neuroanatomía) (id: ??, ns: 0),
#  Cóndilo (id: ??, ns: 0),
#  Conducto ependimario (id: ??, ns: 0),
#  Corazón humano (id: ??, ns: 0),
#  Corpúsculo de Meissner (id: ??, ns: 0),
#  Corpúsculos de Krause (id: ??, ns: 0),
#  Corpúsculos de Pacini (id: ??, ns: 0),
#  Corpúsculos de Ruffini (id: ??, ns: 0),
#  Costilla (id: ??, ns: 0),
#  Cresta (sistema esquelético) (id: ??, ns: 0),
#  Cuadrilátero humerotricipital (id: ??, ns: 0),
#  Cuerpo (anatomía) (id: ??, ns: 0),
#  Dactilia (id: ??, ns: 0),
#  Decúbito (id: ??, ns: 0),
#  Decúbito lateral (id: ??, ns: 0),
#  Decúbito prono (id: ??, ns: 0),
#  Decúbito supino (id: ??, ns: 0),
#  Diáfisis (id: ??, ns: 0),
#  Disección (id: ??, ns: 0),
#  Distal (id: ??, ns: 0),
#  Conducto arterioso (id: ??, ns: 0),
#  Ectasia (id: ??, ns: 0),
#  Ectotimpánico (id: ??, ns: 0),
#  Endocardio (id: ??, ns: 0),
#  Epicardio (id: ??, ns: 0),
#  Epicóndilo (id: ??, ns: 0),
#  Epífisis (id: ??, ns: 0),
#  Espacio anatómico (id: ??, ns: 0),
#  Espacio intercostal (id: ??, ns: 0),
#  Esqueleto (id: ??, ns: 0),
#  Estatura baja familiar (id: ??, ns: 0),
#  Estómago (id: ??, ns: 0),
#  Estrato lúcido (id: ??, ns: 0),
#  Extremidad (id: ??, ns: 0),
#  Fabela (id: ??, ns: 0),
#  Fascia (id: ??, ns: 0),
#  Fascia renal (id: ??, ns: 0),
#  Fascintegridad (id: ??, ns: 0),
#  Fisiología gastrointestinal (id: ??, ns: 0),
#  Fisis (id: ??, ns: 0),
#  Flexión (anatomía) (id: ??, ns: 0),
#  Foramen infraorbitario (id: ??, ns: 0),
#  Foramen magno (id: ??, ns: 0),
#  Fosa (anatomía) (id: ??, ns: 0),
#  Foundational Model of Anatomy (id: ??, ns: 0),
#  Foveola gástrica (id: ??, ns: 0),
#  Ganglio (id: ??, ns: 0),
#  Glabro (id: ??, ns: 0),
#  Glande del clítoris (id: ??, ns: 0),
#  Glándulas gástricas (id: ??, ns: 0),
#  Gránulos de Birbeck (id: ??, ns: 0),
#  Hallux (id: ??, ns: 0),
#  Hipófisis (id: ??, ns: 0),
#  Hipoplasia del nervio óptico (id: ??, ns: 0),
#  Hueso accesorio (id: ??, ns: 0),
#  ...]

# %%
len(subcategories)
# Out:
# 505

# %%
len(articles)
# Out:
# 11881

# %%
    for subcategory in category.categorymembers.values():
        if subcategory.ns == wikipediaapi.Namespace.CATEGORY:
            subcategories.append(subcategory)
            subcategories.extend(get_subcategories(subcategory, depth + 1, max_depth))
    return subcategories

def get_articles(category, articles_set):
    articles = []
    for member in category.categorymembers.values():
        if member.ns == wikipediaapi.Namespace.MAIN:
            if member.title not in articles_set:
                articles.append(member)
                articles_set.add(member.title)
    return articles

wiki_wiki = wikipediaapi.Wikipedia("papapa", 'es')

category_name = "Categoría:Ciencias de la vida"
category = wiki_wiki.page(category_name)

if not category.exists():
    print(f"Category '{category_name}' does not exist.")


max_depth = 5
subcategories = get_subcategories(category, 4, max_depth)

articles_set = set()
articles = get_articles(category, articles_set)

for subcategory in subcategories:
    articles.extend(get_articles(subcategory, articles_set))

for article in articles:
    print(article.title, article.fullurl)

# %%
def print_langlinks(page):
        langlinks = page.langlinks
        for k in sorted(langlinks.keys()):
            v = langlinks[k]
            print("%s: %s - %s: %s" % (k, v.language, v.title, v.fullurl))

print_langlinks(page_py)
# Out:
# af: af - Python (programmeertaal): https://af.wikipedia.org/wiki/Python_(programmeertaal)
# als: als - Python (Programmiersprache): https://als.wikipedia.org/wiki/Python_(Programmiersprache)
# an: an - Python: https://an.wikipedia.org/wiki/Python
# ar: ar - بايثون (لغة برمجة): https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D9%84%D8%BA%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D8%A9)
# as: as - পাইথন: https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8
# ast: ast - Python: https://ast.wikipedia.org/wiki/Python
# az: az - Python (proqramlaşdırma dili): https://az.wikipedia.org/wiki/Python_(proqramla%C5%9Fd%C4%B1rma_dili)
# azb: azb - پایتون: https://azb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86
# ban: ban - Python: https://ban.wikipedia.org/wiki/Python
# be: be - Python (мова праграмавання): https://be.wikipedia.org/wiki/Python_(%D0%BC%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F)
# bg: bg - Python: https://bg.wikipedia.org/wiki/Python
# bh: bh - पाइथन: https://bh.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8
# bn: bn - পাইথন (প্রোগ্রামিং ভাষা): https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE)
# br: br - Python (lavar programmiñ): https://br.wikipedia.org/wiki/Python_(lavar_programmi%C3%B1)
# bs: bs - Python (programski jezik): https://bs.wikipedia.org/wiki/Python_(programski_jezik)
# bug: bug - Python: https://bug.wikipedia.org/wiki/Python
# ca: ca - Python: https://ca.wikipedia.org/wiki/Python
# ceb: ceb - Python (programming language): https://ceb.wikipedia.org/wiki/Python_(programming_language)
# ckb: ckb - پایتۆن (زمانی بەرنامەسازی): https://ckb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%DB%86%D9%86_(%D8%B2%D9%85%D8%A7%D9%86%DB%8C_%D8%A8%DB%95%D8%B1%D9%86%D8%A7%D9%85%DB%95%D8%B3%D8%A7%D8%B2%DB%8C)
# cs: cs - Python: https://cs.wikipedia.org/wiki/Python
# cy: cy - Python (iaith raglennu): https://cy.wikipedia.org/wiki/Python_(iaith_raglennu)
# da: da - Python (programmeringssprog): https://da.wikipedia.org/wiki/Python_(programmeringssprog)
# de: de - Python (Programmiersprache): https://de.wikipedia.org/wiki/Python_(Programmiersprache)
# el: el - Python: https://el.wikipedia.org/wiki/Python
# eo: eo - Python (programlingvo): https://eo.wikipedia.org/wiki/Python_(programlingvo)
# es: es - Python: https://es.wikipedia.org/wiki/Python
# et: et - Python (programmeerimiskeel): https://et.wikipedia.org/wiki/Python_(programmeerimiskeel)
# eu: eu - Python (informatika): https://eu.wikipedia.org/wiki/Python_(informatika)
# fa: fa - پایتون (زبان برنامه‌نویسی): https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86_(%D8%B2%D8%A8%D8%A7%D9%86_%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C)
# fi: fi - Python (ohjelmointikieli): https://fi.wikipedia.org/wiki/Python_(ohjelmointikieli)
# fj: fj - Python: https://fj.wikipedia.org/wiki/Python
# fr: fr - Python (langage): https://fr.wikipedia.org/wiki/Python_(langage)
# gl: gl - Python: https://gl.wikipedia.org/wiki/Python
# gu: gu - પાયથોન(પ્રોગ્રામિંગ ભાષા): https://gu.wikipedia.org/wiki/%E0%AA%AA%E0%AA%BE%E0%AA%AF%E0%AA%A5%E0%AB%8B%E0%AA%A8(%E0%AA%AA%E0%AB%8D%E0%AA%B0%E0%AB%8B%E0%AA%97%E0%AB%8D%E0%AA%B0%E0%AA%BE%E0%AA%AE%E0%AA%BF%E0%AA%82%E0%AA%97_%E0%AA%AD%E0%AA%BE%E0%AA%B7%E0%AA%BE)
# ha: ha - Python programming language: https://ha.wikipedia.org/wiki/Python_programming_language
# he: he - פייתון: https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%99%D7%AA%D7%95%D7%9F
# hi: hi - पाइथन: https://hi.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8
# hr: hr - Python (programski jezik): https://hr.wikipedia.org/wiki/Python_(programski_jezik)
# hu: hu - Python (programozási nyelv): https://hu.wikipedia.org/wiki/Python_(programoz%C3%A1si_nyelv)
# hy: hy - Python: https://hy.wikipedia.org/wiki/Python
# ia: ia - Python (linguage de programmation): https://ia.wikipedia.org/wiki/Python_(linguage_de_programmation)
# id: id - Python (bahasa pemrograman): https://id.wikipedia.org/wiki/Python_(bahasa_pemrograman)
# io: io - Python: https://io.wikipedia.org/wiki/Python
# is: is - Python (forritunarmál): https://is.wikipedia.org/wiki/Python_(forritunarm%C3%A1l)
# it: it - Python: https://it.wikipedia.org/wiki/Python
# ja: ja - Python: https://ja.wikipedia.org/wiki/Python
# jbo: jbo - paiton: https://jbo.wikipedia.org/wiki/paiton
# ka: ka - პაითონი (პროგრამირების ენა): https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%90%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%94%E1%83%91%E1%83%98%E1%83%A1_%E1%83%94%E1%83%9C%E1%83%90)
# kaa: kaa - Python (programmalastırıw tili): https://kaa.wikipedia.org/wiki/Python_(programmalast%C4%B1r%C4%B1w_tili)
# kk: kk - Python: https://kk.wikipedia.org/wiki/Python
# km: km - ផាយថុន: https://km.wikipedia.org/wiki/%E1%9E%95%E1%9E%B6%E1%9E%99%E1%9E%90%E1%9E%BB%E1%9E%93
# ko: ko - 파이썬: https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC
# ku: ku - Python (zimanê bernamesaziyê): https://ku.wikipedia.org/wiki/Python_(ziman%C3%AA_bernamesaziy%C3%AA)
# ky: ky - Python: https://ky.wikipedia.org/wiki/Python
# la: la - Python (lingua programmandi): https://la.wikipedia.org/wiki/Python_(lingua_programmandi)
# lmo: lmo - Python: https://lmo.wikipedia.org/wiki/Python
# lt: lt - Python: https://lt.wikipedia.org/wiki/Python
# lv: lv - Python (programmēšanas valoda): https://lv.wikipedia.org/wiki/Python_(programm%C4%93%C5%A1anas_valoda)
# mk: mk - Пајтон (програмски јазик): https://mk.wikipedia.org/wiki/%D0%9F%D0%B0%D1%98%D1%82%D0%BE%D0%BD_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B0%D0%B7%D0%B8%D0%BA)
# ml: ml - പൈത്തൺ (പ്രോഗ്രാമിങ്ങ് ഭാഷ): https://ml.wikipedia.org/wiki/%E0%B4%AA%E0%B5%88%E0%B4%A4%E0%B5%8D%E0%B4%A4%E0%B5%BA_(%E0%B4%AA%E0%B5%8D%E0%B4%B0%E0%B5%8B%E0%B4%97%E0%B5%8D%E0%B4%B0%E0%B4%BE%E0%B4%AE%E0%B4%BF%E0%B4%99%E0%B5%8D%E0%B4%99%E0%B5%8D_%E0%B4%AD%E0%B4%BE%E0%B4%B7)
# mn: mn - Python: https://mn.wikipedia.org/wiki/Python
# mr: mr - पायथॉन: https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8
# ms: ms - Python: https://ms.wikipedia.org/wiki/Python
# my: my - Python (programming language): https://my.wikipedia.org/wiki/Python_(programming_language)
# nb: nb - Python: https://no.wikipedia.org/wiki/Python
# nds: nds - Python (Programmeerspraak): https://nds.wikipedia.org/wiki/Python_(Programmeerspraak)
# ne: ne - पाइथन (प्रोगामिङ भाषा): https://ne.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8_(%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%99_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE)
# nl: nl - Python (programmeertaal): https://nl.wikipedia.org/wiki/Python_(programmeertaal)
# nn: nn - Python: https://nn.wikipedia.org/wiki/Python
# nqo: nqo - ߔߊߌߕߐ߲߬: https://nqo.wikipedia.org/wiki/%DF%94%DF%8A%DF%8C%DF%95%DF%90%DF%B2%DF%AC
# or: or - ପାଇଥନ୍ (ପ୍ରୋଗ୍ରାମିଂ ଭାଷା): https://or.wikipedia.org/wiki/%E0%AC%AA%E0%AC%BE%E0%AC%87%E0%AC%A5%E0%AC%A8%E0%AD%8D_(%E0%AC%AA%E0%AD%8D%E0%AC%B0%E0%AD%8B%E0%AC%97%E0%AD%8D%E0%AC%B0%E0%AC%BE%E0%AC%AE%E0%AC%BF%E0%AC%82_%E0%AC%AD%E0%AC%BE%E0%AC%B7%E0%AC%BE)
# pa: pa - ਪਾਈਥਨ (ਪ੍ਰੋਗਰਾਮਿੰਗ ਭਾਸ਼ਾ): https://pa.wikipedia.org/wiki/%E0%A8%AA%E0%A8%BE%E0%A8%88%E0%A8%A5%E0%A8%A8_(%E0%A8%AA%E0%A9%8D%E0%A8%B0%E0%A9%8B%E0%A8%97%E0%A8%B0%E0%A8%BE%E0%A8%AE%E0%A8%BF%E0%A9%B0%E0%A8%97_%E0%A8%AD%E0%A8%BE%E0%A8%B8%E0%A8%BC%E0%A8%BE)
# pl: pl - Python: https://pl.wikipedia.org/wiki/Python
# pnb: pnb - پائیتھن (کمپیوٹر بولی): https://pnb.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%86_(%DA%A9%D9%85%D9%BE%DB%8C%D9%88%D9%B9%D8%B1_%D8%A8%D9%88%D9%84%DB%8C)
# pt: pt - Python: https://pt.wikipedia.org/wiki/Python
# qu: qu - Python: https://qu.wikipedia.org/wiki/Python
# ro: ro - Python: https://ro.wikipedia.org/wiki/Python
# ru: ru - Python: https://ru.wikipedia.org/wiki/Python
# sah: sah - Python: https://sah.wikipedia.org/wiki/Python
# sat: sat - ᱯᱟᱭᱛᱷᱚᱱ (ᱯᱨᱳᱜᱽᱨᱟᱢᱤᱝ ᱯᱟᱹᱨᱥᱤ): https://sat.wikipedia.org/wiki/%E1%B1%AF%E1%B1%9F%E1%B1%AD%E1%B1%9B%E1%B1%B7%E1%B1%9A%E1%B1%B1_(%E1%B1%AF%E1%B1%A8%E1%B1%B3%E1%B1%9C%E1%B1%BD%E1%B1%A8%E1%B1%9F%E1%B1%A2%E1%B1%A4%E1%B1%9D_%E1%B1%AF%E1%B1%9F%E1%B1%B9%E1%B1%A8%E1%B1%A5%E1%B1%A4)
# sco: sco - Python (programmin leid): https://sco.wikipedia.org/wiki/Python_(programmin_leid)
# sh: sh - Python programski jezik: https://sh.wikipedia.org/wiki/Python_programski_jezik
# shn: shn - Python (programming language): https://shn.wikipedia.org/wiki/Python_(programming_language)
# si: si - පයිතන්: https://si.wikipedia.org/wiki/%E0%B6%B4%E0%B6%BA%E0%B7%92%E0%B6%AD%E0%B6%B1%E0%B7%8A
# simple: simple - Python (programming language): https://simple.wikipedia.org/wiki/Python_(programming_language)
# sk: sk - Python (programovací jazyk): https://sk.wikipedia.org/wiki/Python_(programovac%C3%AD_jazyk)
# sl: sl - Python (programski jezik): https://sl.wikipedia.org/wiki/Python_(programski_jezik)
# sq: sq - Python: https://sq.wikipedia.org/wiki/Python
# sr: sr - Python (програмски језик): https://sr.wikipedia.org/wiki/Python_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B5%D0%B7%D0%B8%D0%BA)
# sv: sv - Python (programspråk): https://sv.wikipedia.org/wiki/Python_(programspr%C3%A5k)
# sw: sw - Python (Lugha ya programu): https://sw.wikipedia.org/wiki/Python_(Lugha_ya_programu)
# ta: ta - பைத்தான்: https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%88%E0%AE%A4%E0%AF%8D%E0%AE%A4%E0%AE%BE%E0%AE%A9%E0%AF%8D
# te: te - పైథాన్ (కంప్యూటర్ భాష): https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%88%E0%B0%A5%E0%B0%BE%E0%B0%A8%E0%B1%8D_(%E0%B0%95%E0%B0%82%E0%B0%AA%E0%B1%8D%E0%B0%AF%E0%B1%82%E0%B0%9F%E0%B0%B0%E0%B1%8D_%E0%B0%AD%E0%B0%BE%E0%B0%B7)
# tg: tg - Python: https://tg.wikipedia.org/wiki/Python
# th: th - ภาษาไพทอน: https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99
# tl: tl - Python (wikang pamprograma): https://tl.wikipedia.org/wiki/Python_(wikang_pamprograma)
# tr: tr - Python: https://tr.wikipedia.org/wiki/Python
# tt: tt - Python: https://tt.wikipedia.org/wiki/Python
# ug: ug - پايسون: https://ug.wikipedia.org/wiki/%D9%BE%D8%A7%D9%8A%D8%B3%D9%88%D9%86
# uk: uk - Python: https://uk.wikipedia.org/wiki/Python
# ur: ur - پائیتھن (پروگرامنگ زبان): https://ur.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%86_(%D9%BE%D8%B1%D9%88%DA%AF%D8%B1%D8%A7%D9%85%D9%86%DA%AF_%D8%B2%D8%A8%D8%A7%D9%86)
# uz: uz - Python: https://uz.wikipedia.org/wiki/Python
# vi: vi - Python (ngôn ngữ lập trình): https://vi.wikipedia.org/wiki/Python_(ng%C3%B4n_ng%E1%BB%AF_l%E1%BA%ADp_tr%C3%ACnh)
# wa: wa - Python (lingaedje éndjolike): https://wa.wikipedia.org/wiki/Python_(lingaedje_%C3%A9ndjolike)
# war: war - Python (programming language): https://war.wikipedia.org/wiki/Python_(programming_language)
# wuu: wuu - Python: https://wuu.wikipedia.org/wiki/Python
# zh: zh - Python: https://zh.wikipedia.org/wiki/Python
# zh-classical: zh-classical - 蟒語: https://zh-classical.wikipedia.org/wiki/%E8%9F%92%E8%AA%9E
# zh-min-nan: zh-min-nan - Python: https://zh-min-nan.wikipedia.org/wiki/Python
# zh-yue: zh-yue - Python: https://zh-yue.wikipedia.org/wiki/Python
